# %%
from posixpath import join
import cvxopt
import cvxopt
from cvxopt import solvers
import random
import matplotlib.pyplot as plt
from numpy.lib.function_base import average
import torch
from autograd import grad
from autograd import jacobian
import autograd.numpy as np
import autograd.numpy as jnp
import scipy.optimize as optim
from scipy.optimize import minimize, Bounds,LinearConstraint
from scipy.optimize import LinearConstraint,NonlinearConstraint
from scipy.optimize import BFGS
from  autograd.numpy import cos,sin
import pdb
t = 0.02
q_prev = None

device = 'cpu'
model = torch.load('models/model_750_model_epoch_20000.pth', map_location=torch.device('cpu'))  # loaded trained model #TODO
q_dim = 6  # q_dim is the dimension of joint space
q_dim_changed = int(0.5 * q_dim)

#WEIGHT for cost for optimizer 
w_des_vel = 0.002
weight_orient = 0.2
#DESIRED
roll_des= -3.141105126296926
pitch_des= 0.00046035505135551175
yaw_des = -2.355906195444897


#value function defnation
weight = []
for key in (model.keys()):
    # print(key)
    weight.append(model[key].cpu().numpy())  # load weight and bias


def leaky_relu(z):
    return np.maximum(0.01 * z, z)


def softplus(z, beta=1):
    return (1 / beta) * np.log(1 + np.exp(z * beta))


def assemble_lower_triangular_matrix(Lo, Ld):
    Lo = Lo.squeeze(0)
    Ld = Ld.squeeze(0)

    assert (2 * Lo.shape[0] == (Ld.shape[0] ** 2 - Ld.shape[0]))
    # pdb.set_trace()
    #     diagonal_matrix = np.diagflat(Ld)
    diagonal_matrix = np.identity(len(Ld)) * np.outer(np.ones(len(Ld)), Ld)

    L = np.tril(np.ones(diagonal_matrix.shape)) - np.eye(q_dim_changed)

    # Set off diagonals

    L = np.array([[0, 0, 0], [1, 0, 0], [0, 0, 0]]) * Lo.reshape(3)[0] + np.array([[0, 0, 0], [0, 0, 0], [1, 0, 0]]) * \
        Lo.reshape(3)[1] + np.array([[0, 0, 0], [0, 0, 0], [0, 1, 0]]) * Lo.reshape(3)[2]
    # print("L now : ", L)
    # Add diagonals
    L = L + diagonal_matrix
    return L


def value(x1):
    global weight, goal
    fc1_w = weight[0]
    fc1_b = weight[1]
    fc2_w = weight[2]
    fc2_b = weight[3]
    fc_Ld_w = weight[4]
    fc_Ld_b = weight[5]
    fc_Lo_w = weight[6]
    fc_Lo_b = weight[7]
    #pdb.set_trace()
    net_input = np.concatenate([np.squeeze(x1), np.squeeze(goal)], axis=0)
    net_input = np.array([net_input])

    z1 = np.dot(net_input, fc1_w.transpose()) + fc1_b
    hidden1 = leaky_relu(z1)
    z2 = np.dot(hidden1, fc2_w.transpose()) + fc2_b
    hidden2 = leaky_relu(z2)
    hidden3 = np.dot(hidden2, fc_Ld_w.transpose()) + fc_Ld_b
    Ld = softplus(hidden3)
    Lo = np.dot(hidden2, fc_Lo_w.transpose()) + fc_Lo_b
    L = assemble_lower_triangular_matrix(Lo, Ld)

    H = L @ L.transpose() + 1e-9 * np.eye(3)
    return H

grad_value = grad(value)
jac_value= jacobian(value)

def fk_franka(q):
    q_1 = q[0]
    q_2 = q[1]
    q_3 = q[2]
    q_4 = q[3]
    q_5 = q[4]
    q_6 = q[5]
    q_7 = q[6]

    x = -0.107*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) - 0.088*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.cos(q_6) + 0.088*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.sin(q_6) - 0.107*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.384*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + 0.0825*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_3) - 0.0825*np.sin(q_2)*np.sin(q_4)*np.cos(q_1) + 0.384*np.sin(q_2)*np.cos(q_1)*np.cos(q_4) + 0.316*np.sin(q_2)*np.cos(q_1) + 0.0825*np.cos(q_1)*np.cos(q_2)*np.cos(q_3)

    y = 0.107*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.088*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.cos(q_6) - 0.088*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.sin(q_6) + 0.107*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.384*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - 0.0825*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_2)*np.sin(q_4) + 0.384*np.sin(q_1)*np.sin(q_2)*np.cos(q_4) + 0.316*np.sin(q_1)*np.sin(q_2) + 0.0825*np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + 0.0825*np.sin(q_3)*np.cos(q_1)

    z = -0.107*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.sin(q_6) - 0.088*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) + 0.088*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6) - 0.107*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.cos(q_6) + 0.384*np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + 0.0825*np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - 0.0825*np.sin(q_2)*np.cos(q_3) - 0.0825*np.sin(q_4)*np.cos(q_2) + 0.384*np.cos(q_2)*np.cos(q_4) + 0.316*np.cos(q_2) + 0.33

    tr = np.sin(q_2)*np.sin(q_3)*np.sin(q_5)*np.sin(q_6) + np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.sin(q_1 + q_7) - np.sin(q_2)*np.sin(q_4)*np.cos(q_3)*np.cos(q_6) + np.sin(q_2)*np.sin(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - np.sin(q_2)*np.sin(q_6)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5) + np.sin(q_2)*np.sin(q_6)*np.cos(q_4)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7) - np.sin(q_3)*np.sin(q_5)*np.cos(q_2)*np.cos(q_6)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_5)*np.cos(q_4)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_5) - np.sin(q_3)*np.sin(q_1 + q_7)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - np.sin(q_4)*np.sin(q_6)*np.cos(q_2)*np.cos(q_3)*np.cos(q_1 + q_7) + np.sin(q_4)*np.sin(q_6)*np.cos(q_2)*np.cos(q_5) + np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_6) + np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - np.cos(q_2)*np.cos(q_4)*np.cos(q_6) - np.cos(q_3)*np.cos(q_5)*np.cos(q_1 + q_7)

    ax1 = -0.5*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.sin(q_7) - 0.5*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.cos(q_7)

    ax2 = -0.5*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.cos(q_7) - 0.5*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.sin(q_7)

    ax3 = -0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_1 + q_7)*np.cos(q_5)*np.cos(q_6) + 0.5*np.sin(q_2)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_6) + 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.cos(q_2)*np.cos(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3) - 0.5*np.sin(q_5)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_1 + q_7) + 0.5*np.sin(q_5)*np.cos(q_3)*np.cos(q_6)*np.cos(q_1 + q_7) + 0.5*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - 0.5*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_5)

    cartpos = np.array([x,y,z])
    return cartpos
jac_fk = jacobian(fk_franka)
def fk_franka_orient(q):
    
    q_1 = q[0]
    q_2 = q[1]
    q_3 = q[2]
    q_4 = q[3]
    q_5 = q[4]
    q_6 = q[5]
    q_7 = q[6]

    x = -0.107*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) - 0.088*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.cos(q_6) + 0.088*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.sin(q_6) - 0.107*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.384*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + 0.0825*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_3) - 0.0825*np.sin(q_2)*np.sin(q_4)*np.cos(q_1) + 0.384*np.sin(q_2)*np.cos(q_1)*np.cos(q_4) + 0.316*np.sin(q_2)*np.cos(q_1) + 0.0825*np.cos(q_1)*np.cos(q_2)*np.cos(q_3)

    y = 0.107*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.088*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.cos(q_6) - 0.088*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.sin(q_6) + 0.107*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.384*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - 0.0825*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_2)*np.sin(q_4) + 0.384*np.sin(q_1)*np.sin(q_2)*np.cos(q_4) + 0.316*np.sin(q_1)*np.sin(q_2) + 0.0825*np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + 0.0825*np.sin(q_3)*np.cos(q_1)

    z = -0.107*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.sin(q_6) - 0.088*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) + 0.088*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6) - 0.107*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.cos(q_6) + 0.384*np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + 0.0825*np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - 0.0825*np.sin(q_2)*np.cos(q_3) - 0.0825*np.sin(q_4)*np.cos(q_2) + 0.384*np.cos(q_2)*np.cos(q_4) + 0.316*np.cos(q_2) + 0.33

    cq1 = np.cos(q_1)
    cq2 = np.cos(q_2)
    cq3 = np.cos(q_3)
    cq4 = np.cos(q_4)
    cq5 = np.cos(q_5)
    cq6 = np.cos(q_6)
    cq7 = np.cos(q_7)

    sq1 = np.sin(q_1)
    sq2 = np.sin(q_2)
    sq3 = np.sin(q_3)
    sq4 = np.sin(q_4)
    sq5 = np.sin(q_5)
    sq6 = np.sin(q_6)
    sq7 = np.sin(q_7)
    ax1 = -0.5*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.sin(q_7) - 0.5*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.cos(q_7)

    ax2 = -0.5*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.cos(q_7) - 0.5*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.sin(q_7)

    ax3 = -0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_1 + q_7)*np.cos(q_5)*np.cos(q_6) + 0.5*np.sin(q_2)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_6) + 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.cos(q_2)*np.cos(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3) - 0.5*np.sin(q_5)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_1 + q_7) + 0.5*np.sin(q_5)*np.cos(q_3)*np.cos(q_6)*np.cos(q_1 + q_7) + 0.5*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - 0.5*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_5)

    r_32 = -cq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2)) - sq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4))
    r_33 = -cq6*(cq2*cq4 + cq3*sq2*sq4) + sq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5)
    r_31 = cq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4)) - sq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2))
    r_21 = cq7*(cq6*(cq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4) + sq5*(cq1*cq3 - cq2*sq1*sq3)) + sq6*(cq4*sq1*sq2 - sq4*(cq1*sq3 + cq2*cq3*sq1))) - sq7*(cq5*(cq1*cq3 - cq2*sq1*sq3) - sq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4))
    r_11 = cq7*(cq6*(cq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)) - sq5*(cq1*cq2*sq3 + cq3*sq1)) + sq6*(cq1*cq4*sq2 - sq4*(cq1*cq2*cq3 - sq1*sq3))) + sq7*(cq5*(cq1*cq2*sq3 + cq3*sq1) + sq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)))
    roll_ = np.arctan2(r_32, r_33)
    pitch_=-np.arcsin(r_31)
    yaw_ = np.arctan2(r_21,r_11)
    cartpos = np.array([x,y,z])
    pos = [x,y,z,roll_,pitch_,yaw_]
    return pos
def traj_cost(trajectory):
    #pdb.set_trace()
    cost = 0
    cart_cost = 0
    for i in range(len(trajectory) - 1):
        cost += np.linalg.norm(np.asarray(trajectory[i]) - np.asarray(trajectory[i + 1]), ord=2)
        # pdb.set_trace()
        current = np.asarray(fk_franka(trajectory[i]))  #TODO
        next = np.asarray(fk_franka(trajectory[i+1])) #TODO
        cart_cost += np.linalg.norm(current - next, ord=2)
    return cost, cart_cost




def constraintfxn(qdot_x_next):
    global t, q_prev
    q = qdot_x_next[:7]*t  + q_prev
    x_next = qdot_x_next[7]
    y_next = qdot_x_next[8]
    z_next = qdot_x_next[9]

    # x,y,z= robot.fkine(q) #TODO
    q_1 = q[0]
    q_2 = q[1]
    q_3 = q[2]
    q_4 = q[3]
    q_5 = q[4]
    q_6 = q[5]
    q_7 = q[6]


    x = -0.107*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) - 0.088*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.cos(q_6) + 0.088*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.sin(q_6) - 0.107*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.384*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + 0.0825*(np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_3) - 0.0825*np.sin(q_2)*np.sin(q_4)*np.cos(q_1) + 0.384*np.sin(q_2)*np.cos(q_1)*np.cos(q_4) + 0.316*np.sin(q_2)*np.cos(q_1) + 0.0825*np.cos(q_1)*np.cos(q_2)*np.cos(q_3)

    y = 0.107*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.088*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.cos(q_6) - 0.088*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.sin(q_6) + 0.107*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.384*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - 0.0825*(np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) - 0.0825*np.sin(q_1)*np.sin(q_2)*np.sin(q_4) + 0.384*np.sin(q_1)*np.sin(q_2)*np.cos(q_4) + 0.316*np.sin(q_1)*np.sin(q_2) + 0.0825*np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + 0.0825*np.sin(q_3)*np.cos(q_1)

    z = -0.107*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.sin(q_6) - 0.088*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) + 0.088*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6) - 0.107*(np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.cos(q_6) + 0.384*np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + 0.0825*np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - 0.0825*np.sin(q_2)*np.cos(q_3) - 0.0825*np.sin(q_4)*np.cos(q_2) + 0.384*np.cos(q_2)*np.cos(q_4) + 0.316*np.cos(q_2) + 0.33

    tr = np.sin(q_2)*np.sin(q_3)*np.sin(q_5)*np.sin(q_6) + np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.sin(q_1 + q_7) - np.sin(q_2)*np.sin(q_4)*np.cos(q_3)*np.cos(q_6) + np.sin(q_2)*np.sin(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - np.sin(q_2)*np.sin(q_6)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5) + np.sin(q_2)*np.sin(q_6)*np.cos(q_4)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7) - np.sin(q_3)*np.sin(q_5)*np.cos(q_2)*np.cos(q_6)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_5)*np.cos(q_4)*np.cos(q_1 + q_7) + np.sin(q_3)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_5) - np.sin(q_3)*np.sin(q_1 + q_7)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - np.sin(q_4)*np.sin(q_6)*np.cos(q_2)*np.cos(q_3)*np.cos(q_1 + q_7) + np.sin(q_4)*np.sin(q_6)*np.cos(q_2)*np.cos(q_5) + np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_6) + np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - np.cos(q_2)*np.cos(q_4)*np.cos(q_6) - np.cos(q_3)*np.cos(q_5)*np.cos(q_1 + q_7)

    ax1 = -0.5*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.sin(q_7) - 0.5*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.cos(q_7)

    ax2 = -0.5*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.cos(q_7) - 0.5*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.sin(q_7)

    ax3 = -0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_1 + q_7)*np.cos(q_5)*np.cos(q_6) + 0.5*np.sin(q_2)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_6) + 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.cos(q_2)*np.cos(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3) - 0.5*np.sin(q_5)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_1 + q_7) + 0.5*np.sin(q_5)*np.cos(q_3)*np.cos(q_6)*np.cos(q_1 + q_7) + 0.5*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - 0.5*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_5)

    pos_residual = np.array([x - x_next,y-y_next,z - z_next])
    return pos_residual
jac_constraint = jacobian(constraintfxn) #TODO


def orienResidual(q):
  global roll_des,pitch_des, yaw_des
  q_1 = q[0]
  q_2 = q[1]
  q_3 = q[2]
  q_4 = q[3]
  q_5 = q[4]
  q_6 = q[5]
  q_7 = q[6]

  cq1 = np.cos(q_1)
  cq2 = np.cos(q_2)
  cq3 = np.cos(q_3)
  cq4 = np.cos(q_4)
  cq5 = np.cos(q_5)
  cq6 = np.cos(q_6)
  cq7 = np.cos(q_7)

  sq1 = np.sin(q_1)
  sq2 = np.sin(q_2)
  sq3 = np.sin(q_3)
  sq4 = np.sin(q_4)
  sq5 = np.sin(q_5)
  sq6 = np.sin(q_6)
  sq7 = np.sin(q_7)
  ax1 = -0.5*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.sin(q_7) - 0.5*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.cos(q_7)

  ax2 = -0.5*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.cos(q_7) - 0.5*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.sin(q_7)

  ax3 = -0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_1 + q_7)*np.cos(q_5)*np.cos(q_6) + 0.5*np.sin(q_2)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_6) + 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.cos(q_2)*np.cos(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3) - 0.5*np.sin(q_5)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_1 + q_7) + 0.5*np.sin(q_5)*np.cos(q_3)*np.cos(q_6)*np.cos(q_1 + q_7) + 0.5*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - 0.5*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_5)

  r_32 = -cq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2)) - sq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4))
  r_33 = -cq6*(cq2*cq4 + cq3*sq2*sq4) + sq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5)
  r_31 = cq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4)) - sq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2))
  r_21 = cq7*(cq6*(cq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4) + sq5*(cq1*cq3 - cq2*sq1*sq3)) + sq6*(cq4*sq1*sq2 - sq4*(cq1*sq3 + cq2*cq3*sq1))) - sq7*(cq5*(cq1*cq3 - cq2*sq1*sq3) - sq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4))
  r_11 = cq7*(cq6*(cq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)) - sq5*(cq1*cq2*sq3 + cq3*sq1)) + sq6*(cq1*cq4*sq2 - sq4*(cq1*cq2*cq3 - sq1*sq3))) + sq7*(cq5*(cq1*cq2*sq3 + cq3*sq1) + sq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)))
  #pdb.set_trace()
  f_orient_cost = np.sum(  ((r_32/r_33)-np.tan(roll_des))**2+(-np.sin(r_31)-np.sin(pitch_des))**2  +  (np.arctan2(r_21,r_11) -yaw_des )**2 )
  return  f_orient_cost


def compute_franka_jac(qdot_x_next):

    global q_prev,t
    qdot = qdot_x_next[:7]
    qinit =  q_prev  
    qdot_1 = qdot[0]
    qdot_2 = qdot[1]
    qdot_3 = qdot[2]
    qdot_4 = qdot[3]
    qdot_5 = qdot[4]
    qdot_6 = qdot[5]
    qdot_7 = qdot[6]
    
    
    qinit_1 = qinit[0]
    qinit_2 = qinit[1]
    qinit_3 = qinit[2]
    qinit_4 = qinit[3]
    qinit_5 = qinit[4]
    qinit_6 = qinit[5]
    qinit_7 = qinit[6]
  
    const_1_q_1 = 0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) - 0.384*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) - 0.316*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2) - 0.0825*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - 0.0825*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1) + (0.088*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) + (-t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5) + 0.088*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) + (-t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5) + 0.107*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.088*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + 0.088*(t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) - 0.107*(t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) + (0.0825*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + 0.0825*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + (0.384*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + 0.384*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4)
    const_1_q_2 = 0.384*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + 0.0825*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) - 0.0825*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - 0.0825*t*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2) + 0.384*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + 0.316*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2) + (0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5)*cos(qdot_1*t + qinit_1) + 0.088*(-t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + t*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5)*cos(qdot_1*t + qinit_1) + 0.107*(-t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + t*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - 0.107*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) + (0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + 0.088*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)
    const_1_q_3 = -0.0825*t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - 0.0825*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2) + (0.088*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5) + 0.088*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5) + 0.107*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (0.0825*t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + 0.0825*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_4*t + qinit_4) + (0.384*t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + 0.384*t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_4*t + qinit_4) + 0.088*(t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_4*t + qinit_4)*sin(qdot_6*t + qinit_6) - 0.107*(t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_4*t + qinit_4)*cos(qdot_6*t + qinit_6)
    const_1_q_4 = -t*(0.0825*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - 0.0825*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + t*(0.384*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - 0.384*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) - 0.384*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1) - 0.0825*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4) + 0.107*(-t*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)*cos(qdot_5*t + qinit_5) + 0.088*(-t*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5)*cos(qdot_6*t + qinit_6) + (-0.107*t*(sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + 0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*cos(qdot_6*t + qinit_6) + (0.088*t*(sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) - 0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*sin(qdot_6*t + qinit_6)
    const_1_q_5 = (-0.107*t*((-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*sin(qdot_5*t + qinit_5) + 0.107*t*(-sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.088*t*((-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*sin(qdot_5*t + qinit_5) + 0.088*t*(-sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6)
    const_1_q_6 = -t*(0.088*((-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*cos(qdot_5*t + qinit_5) - 0.088*(sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + t*(0.107*((-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1))*cos(qdot_5*t + qinit_5) - 0.107*(sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + t*(-0.088*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + 0.088*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) - t*(0.107*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) - 0.107*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)
    const_1_q_7 = 0
    const_2_q_1 = -0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - 0.0825*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1) + 0.384*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4) + 0.316*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1) + 0.0825*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + (0.088*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5) + 0.088*(t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1) + (-t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5) + 0.107*(t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_1*t + qinit_1) + (-t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) + t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - 0.0825*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + (0.384*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - 0.384*t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + (-0.107*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4) - 0.107*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) + (0.088*t*sin(qdot_2*t + qinit_2)*cos(qdot_1*t + qinit_1)*cos(qdot_4*t + qinit_4) + 0.088*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3) - t*cos(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)
    const_2_q_2 = 0.384*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + 0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) - 0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - 0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2) + 0.384*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + 0.316*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2) + (0.088*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5) + 0.088*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + t*sin(qdot_1*t + qinit_1)*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5) + 0.107*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + t*sin(qdot_1*t + qinit_1)*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.107*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) - 0.107*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) + (0.088*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + 0.088*t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)
    const_2_q_3 = -0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) + 0.0825*t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3) + (0.088*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) + t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5) + 0.088*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*(-t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) + t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5) + 0.107*(-t*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - t*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - 0.0825*t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*cos(qdot_4*t + qinit_4) + (0.384*t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - 0.384*t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4) + 0.088*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4)*sin(qdot_6*t + qinit_6) - 0.107*(t*sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - t*cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_4*t + qinit_4)*cos(qdot_6*t + qinit_6)
    const_2_q_4 = t*(-0.384*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - 0.384*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) - t*(-0.0825*sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - 0.0825*sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4) - 0.384*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) - 0.0825*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + (-0.107*t*(-sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + 0.107*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) + (0.088*t*(-sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) - sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) - 0.088*t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6) + 0.107*(-t*(sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4) + t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)*cos(qdot_5*t + qinit_5) + 0.088*(-t*(sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4) + t*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5)*cos(qdot_6*t + qinit_6)
    const_2_q_5 = (-0.107*t*((sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*sin(qdot_5*t + qinit_5) + 0.107*t*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) + cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.088*t*((sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*sin(qdot_5*t + qinit_5) + 0.088*t*(-sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) + cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6)
    const_2_q_6 = -t*(0.088*((sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5) - 0.088*(sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + t*(0.107*((sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*cos(qdot_4*t + qinit_4) + sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5) - 0.107*(sin(qdot_1*t + qinit_1)*sin(qdot_3*t + qinit_3)*cos(qdot_2*t + qinit_2) - cos(qdot_1*t + qinit_1)*cos(qdot_3*t + qinit_3))*sin(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + t*(-0.088*(sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4) + 0.088*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6) - t*(0.107*(sin(qdot_1*t + qinit_1)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + sin(qdot_3*t + qinit_3)*cos(qdot_1*t + qinit_1))*sin(qdot_4*t + qinit_4) - 0.107*sin(qdot_1*t + qinit_1)*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)
    const_2_q_7 = 0
    const_3_q_1 = 0
    const_3_q_2 = 0.0825*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) - 0.384*t*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) - 0.316*t*sin(qdot_2*t + qinit_2) + 0.384*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + 0.0825*t*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) - 0.0825*t*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3) + (-0.088*t*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + 0.088*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*sin(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) - 0.107*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3))*cos(qdot_6*t + qinit_6) + (0.088*t*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5)*cos(qdot_2*t + qinit_2) + 0.088*(-t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) - t*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5)*cos(qdot_2*t + qinit_2) + 0.107*(-t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4) - t*cos(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6)
    const_3_q_3 = -0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_4*t + qinit_4)*sin(qdot_6*t + qinit_6) + 0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_4*t + qinit_4)*cos(qdot_6*t + qinit_6) - 0.384*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_4*t + qinit_4) - 0.0825*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + 0.0825*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3) + (0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5) + 0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_5*t + qinit_5)*cos(qdot_3*t + qinit_3))*cos(qdot_6*t + qinit_6) + (0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4)*cos(qdot_5*t + qinit_5) + 0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_5*t + qinit_5)*cos(qdot_3*t + qinit_3))*sin(qdot_6*t + qinit_6)
    const_3_q_4 = -0.0825*t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + 0.384*t*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) - 0.384*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2) - 0.0825*t*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4) + 0.107*(t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + t*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6)*cos(qdot_5*t + qinit_5) + 0.088*(t*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + t*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_5*t + qinit_5)*cos(qdot_6*t + qinit_6) + (-0.107*t*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + 0.107*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*cos(qdot_6*t + qinit_6) + (0.088*t*sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) - 0.088*t*sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*sin(qdot_6*t + qinit_6)
    const_3_q_5 = (-0.107*t*(-sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5) + 0.107*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*cos(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + (-0.088*t*(-sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*sin(qdot_5*t + qinit_5) + 0.088*t*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*cos(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6)
    const_3_q_6 = -t*(0.088*(-sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5) + 0.088*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5))*sin(qdot_6*t + qinit_6) + t*(0.107*(-sin(qdot_2*t + qinit_2)*cos(qdot_3*t + qinit_3)*cos(qdot_4*t + qinit_4) + sin(qdot_4*t + qinit_4)*cos(qdot_2*t + qinit_2))*cos(qdot_5*t + qinit_5) + 0.107*sin(qdot_2*t + qinit_2)*sin(qdot_3*t + qinit_3)*sin(qdot_5*t + qinit_5))*cos(qdot_6*t + qinit_6) - t*(-0.107*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) - 0.107*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*sin(qdot_6*t + qinit_6) + t*(0.088*sin(qdot_2*t + qinit_2)*sin(qdot_4*t + qinit_4)*cos(qdot_3*t + qinit_3) + 0.088*cos(qdot_2*t + qinit_2)*cos(qdot_4*t + qinit_4))*cos(qdot_6*t + qinit_6)
    const_3_q_7 = 0
    const_1_x = -1
    const_2_x = 0
    const_3_x = 0
    const_1_y = 0
    const_2_y = -1
    const_3_y = 0
    const_1_z = 0
    const_2_z = 0
    const_3_z = -1
    const_1_jac = np.hstack(( const_1_q_1, const_1_q_2, const_1_q_3, const_1_q_4, const_1_q_5, const_1_q_6, const_1_q_7, const_1_x, const_1_y, const_1_z  ))
    const_2_jac = np.hstack(( const_2_q_1, const_2_q_2, const_2_q_3, const_2_q_4, const_2_q_5, const_2_q_6, const_2_q_7, const_2_x, const_2_y, const_2_z  ))
    const_3_jac = np.hstack(( const_3_q_1, const_3_q_2, const_3_q_3, const_3_q_4, const_3_q_5, const_3_q_6, const_3_q_7, const_3_x, const_3_y, const_3_z  ))
    # const_3_jac = np.hstack(( const_3_q_1, const_3_q_2, const_3_q_3, const_3_q_4, const_3_q_5, const_3_q_6, const_3_q_7, const_2_x, const_2_y, const_2_z  )) orignal MISTAKE?
    const_jac = np.vstack(( const_1_jac, const_2_jac, const_3_jac  ))    
    return const_jac

jac_constraintSympy = compute_franka_jac





def costfxn(solverVariable,x_pos,val):
  global goal,diffinCart,roll_des,pitch_des,yaw_des ,w_des_vel,weight_orient
  diff = solverVariable[7:] - goal
  cost = np.matmul(diff.transpose(),np.matmul(val, diff ))
  diffprev = x_pos - goal
  cost_prev =np.matmul(diffprev.transpose(),np.matmul(val, diffprev ))

  smoothness_cost = np.sum(solverVariable[0:7]**2,axis = 0)
  global q_prev, t ,maxCartdist,iteration
  q = solverVariable[:7]*t + q_prev  
  q_1 = q[0]
  q_2 = q[1]
  q_3 = q[2]
  q_4 = q[3]
  q_5 = q[4]
  q_6 = q[5]
  q_7 = q[6]

  cq1 = np.cos(q_1)
  cq2 = np.cos(q_2)
  cq3 = np.cos(q_3)
  cq4 = np.cos(q_4)
  cq5 = np.cos(q_5)
  cq6 = np.cos(q_6)
  cq7 = np.cos(q_7)

  sq1 = np.sin(q_1)
  sq2 = np.sin(q_2)
  sq3 = np.sin(q_3)
  sq4 = np.sin(q_4)
  sq5 = np.sin(q_5)
  sq6 = np.sin(q_6)
  sq7 = np.sin(q_7)
  ax1 = -0.5*(((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.cos(q_4) + np.sin(q_1)*np.sin(q_2)*np.sin(q_4))*np.cos(q_5) - (np.sin(q_1)*np.sin(q_3)*np.cos(q_2) - np.cos(q_1)*np.cos(q_3))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.sin(q_7) - 0.5*((np.sin(q_1)*np.cos(q_2)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1))*np.sin(q_4) - np.sin(q_1)*np.sin(q_2)*np.cos(q_4))*np.cos(q_6) - 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.cos(q_7)

  ax2 = -0.5*(((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.cos(q_4) - np.sin(q_2)*np.sin(q_4)*np.cos(q_1))*np.cos(q_5) + (np.sin(q_1)*np.cos(q_3) + np.sin(q_3)*np.cos(q_1)*np.cos(q_2))*np.sin(q_5))*np.sin(q_6) + 0.5*(((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.cos(q_5) - np.sin(q_2)*np.sin(q_3)*np.sin(q_5))*np.cos(q_6) - (np.sin(q_2)*np.sin(q_4)*np.cos(q_3) + np.cos(q_2)*np.cos(q_4))*np.sin(q_6))*np.cos(q_7) - 0.5*((np.sin(q_1)*np.sin(q_3) - np.cos(q_1)*np.cos(q_2)*np.cos(q_3))*np.sin(q_4) + np.sin(q_2)*np.cos(q_1)*np.cos(q_4))*np.cos(q_6) + 0.5*((np.sin(q_2)*np.cos(q_3)*np.cos(q_4) - np.sin(q_4)*np.cos(q_2))*np.sin(q_5) + np.sin(q_2)*np.sin(q_3)*np.cos(q_5))*np.sin(q_7)

  ax3 = -0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_2)*np.sin(q_4)*np.sin(q_1 + q_7)*np.cos(q_5)*np.cos(q_6) + 0.5*np.sin(q_2)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.sin(q_4)*np.sin(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_6) + 0.5*np.sin(q_3)*np.sin(q_5)*np.sin(q_1 + q_7)*np.cos(q_4) - 0.5*np.sin(q_3)*np.cos(q_2)*np.cos(q_5)*np.cos(q_1 + q_7) + 0.5*np.sin(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6)*np.cos(q_1 + q_7) - 0.5*np.sin(q_4)*np.sin(q_6)*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3) - 0.5*np.sin(q_5)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_1 + q_7) + 0.5*np.sin(q_5)*np.cos(q_3)*np.cos(q_6)*np.cos(q_1 + q_7) + 0.5*np.sin(q_1 + q_7)*np.cos(q_2)*np.cos(q_3)*np.cos(q_4)*np.cos(q_5)*np.cos(q_6) - 0.5*np.sin(q_1 + q_7)*np.cos(q_3)*np.cos(q_5)

  r_32 = -cq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2)) - sq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4))
  r_33 = -cq6*(cq2*cq4 + cq3*sq2*sq4) + sq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5)
  r_31 = cq7*(cq6*(cq5*(cq2*sq4 - cq3*cq4*sq2) + sq2*sq3*sq5) + sq6*(cq2*cq4 + cq3*sq2*sq4)) - sq7*(cq5*sq2*sq3 - sq5*(cq2*sq4 - cq3*cq4*sq2))
  r_21 = cq7*(cq6*(cq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4) + sq5*(cq1*cq3 - cq2*sq1*sq3)) + sq6*(cq4*sq1*sq2 - sq4*(cq1*sq3 + cq2*cq3*sq1))) - sq7*(cq5*(cq1*cq3 - cq2*sq1*sq3) - sq5*(cq4*(cq1*sq3 + cq2*cq3*sq1) + sq1*sq2*sq4))
  r_11 = cq7*(cq6*(cq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)) - sq5*(cq1*cq2*sq3 + cq3*sq1)) + sq6*(cq1*cq4*sq2 - sq4*(cq1*cq2*cq3 - sq1*sq3))) + sq7*(cq5*(cq1*cq2*sq3 + cq3*sq1) + sq5*(cq1*sq2*sq4 + cq4*(cq1*cq2*cq3 - sq1*sq3)))
  #pdb.set_trace()
  f_orient_cost = np.sum(  ((r_32/r_33)-np.tan(roll_des))**2+(-np.sin(r_31)-np.sin(pitch_des))**2  +  (np.arctan2(r_21,r_11) -yaw_des )**2 )
  totalcost = np.add(cost , w_des_vel*smoothness_cost  )  

    #print(f"f_orient cost={f_orient_cost}")
  #sig = 1/(1+np.exp(diffinCart))
  #orientcost =  weight_orient*f_orient_cost/(100*diffinCart)
  #orientcost =  weight_orient*sig*f_orient_cost
  #orientcost = 2*f_orient_cost
  #weight = 1/(2*maxCartdist*diffinCart**0.5)
  #weight = iteration**(1/8)/(maxCartdist*1)
  #weight = 0 
  weight  = weight_orient/cost_prev
  if f_orient_cost< 0.08999999999999999999999 :
  	weight = 0 #(weight_orient/10)/cost_prev
  #if f_orient_cost < 0.06:
    	#weight = (weight_orient/10)/cost_prev
  #print(f"cost={totalcost} ,prevcosst={weight*f_orient_cost} , f_orient_cost = {f_orient_cost}" )
  totalcost = totalcost + weight*f_orient_cost
  return totalcost
jac_cost = jacobian(costfxn)   #jaccost has a shape of (3,)

#if you want to go from A to B  pass the joint position of A  fk(q_a) , x_fin
import time
def trajMetricBased(init_joint,end_cartesian,seq):
    start_cart = np.asarray(fk_franka(init_joint)) 
    global t,q_prev,goal
    print("Start : ",start_cart)
    print("Goal : ", end_cartesian)
    goal = np.squeeze(end_cartesian)
    x_des  = end_cartesian
    num_dof = 7 #franka panda
    qdot = np.zeros(num_dof)  ########## initial velocity
    qdotprev = np.zeros(num_dof)
    q_min = np.array([-165, -100, -165, -165, -165, -1.0, -165]) * np.pi / 180 # TODO
    #q_min = q_min.reshape(7,1)
    q_max = np.array([165, 101, 165, 1.0, 165, 214, 165]) * np.pi / 180  #TODO
    #q_max = q_max.reshape(7,1)


    qdot_max = np.array([2.1750	,2.1750	,2.1750	,2.1750,	2.6100,	2.6100,	2.6100])  #TODO
    qdot_min = -1*qdot_max
    qacc_max = np.array([15,	7.5,	10	,12.5	,15	,20,	20])  #TODO
    qacc_min = -1*qacc_max

    x_pos = np.asarray(fk_franka(init_joint))  ########### initial positions

    q = init_joint
    q_prev = init_joint
      ######### delta t for which the computed velocity is commanded to the robot 3msec
    x_next = fk_franka(qdot*t + q)

    mpc_iter =200#TODO

    q_1 = []
    q_2 = []
    q_3 = []
    q_4 = []
    q_5 = []
    q_6 = []
    q_7 = []
    cost_tracker = []
    trajectory = []
    qdottrajc =[]
    orientResidual =[]
    #pdb.set_trace()
    solverVariable = np.hstack((qdot,x_next))
    x_min = -np.ones(3,)*np.Inf #fk_franka(q_min)
    x_max = np.ones(3,)*np.Inf #fk_franka(q_max)
    solver_minbounds= np.hstack((qdot_min , x_min))
    solver_maxbounds = np.hstack((qdot_max , x_max))
    Amat = np.hstack((np.identity(7),np.zeros((7,3)))) 
    Bmat = np.hstack((np.identity(7),np.zeros((7,3))))
    Total_time = 0
    for i in range(0, mpc_iter):
        print(f"mpc-itr={i}")
        orientResidual.append(orienResidual(q))
        cost_tracker.append(np.linalg.norm(x_pos - x_des))
        print("final-euclid-norm",np.linalg.norm(x_pos - x_des) , "orient-norm" , orienResidual(q) , "seq=" , seq  )
        if np.linalg.norm(x_pos - x_des) < 0.05  and orienResidual(q) < 0.1 :
            break
            #t = 0.003
            # print("Without value velocity",v_des)

        bnds = Bounds(solver_minbounds,solver_maxbounds)
        nonlinear_constraint = NonlinearConstraint(constraintfxn , np.zeros((3,)), np.zeros((3,)) , jac= jac_constraintSympy, hess=BFGS() )

        #linear_constraint_A = LinearConstraint(Amat*t, np.hstack((q_min-q_prev,x_min)), np.hstack((q_max-q_prev, x_max )))
        linear_constraint_A = LinearConstraint(Amat*t, q_min-q_prev, q_max-q_prev)
        #linear_constraint_B = LinearConstraint(Bmat ,np.hstack((qacc_min*t + qdotprev,x_min)), np.hstack((qacc_max*t + qdotprev,x_max)))
        linear_constraint_B = LinearConstraint(Bmat ,qacc_min*t + qdotprev, qacc_max*t + qdotprev )
        defaultopts={ 'maxiter': 80 , 'ftol': 1e-08, 'iprint': 1, 'disp': True, 'eps': 1.4901161193847656e-08, 'finite_diff_rel_step': None}
        val = value(x_pos)
        currentTime = time.time()
        res = minimize(costfxn ,  solverVariable, args =(x_pos,val) , method='SLSQP', jac=jac_cost,
                constraints=[nonlinear_constraint,linear_constraint_A, linear_constraint_B], options=defaultopts ,bounds=bnds)  
        timeTaken = (time.time() - currentTime)
        Total_time += timeTaken
        solverVariable = np.asarray(res['x']).squeeze()
        trajectory.append([q[0], q[1], q[2], q[3], q[4], q[5], q[6]])
        qdottrajc.append(qdotprev)
        q = q + solverVariable[0:7] * t
        x_pos =  fk_franka(q) #solverVariable[7:]  #or x_next
        solverVariable[7:] = x_pos
        qdotprev = solverVariable[0:7]
        q_prev = q
    if len(trajectory) != 0 :
        JointCost, CartCost = traj_cost(trajectory)
    
        averageTime = Total_time/(i+1)
        executionTime = (i+1)*0.02
        OrienResidual  =  orienResidual(q) 
        cart_residual = cost_tracker[-1]
        print("final-euclid-norm",np.linalg.norm(x_pos - x_des) , "orient-norm" , orienResidual(q) )
        return JointCost, CartCost, cost_tracker, trajectory,qdottrajc,OrienResidual
    else:
        return 0, 0, 0 , [], 0 ,0 


def trajMetricBasedZ(init_joint,end_cartesian, seq ):

    global t,q_prev,goal
    print("Start : ",start_cart)
    print("Goal : ", end_cartesian)
    goal = np.squeeze(end_cartesian)
    x_des  = end_cartesian
    num_dof = 7 #franka panda
    qdot = np.zeros(num_dof)  ########## initial velocity
    qdotprev = np.zeros(num_dof)
    q_min = np.array([-165, -100, -165, -165, -165, -1.0, -165]) * np.pi / 180 # TODO
    #q_min = q_min.reshape(7,1)
    q_max = np.array([165, 101, 165, 1.0, 165, 214, 165]) * np.pi / 180  #TODO
    #q_max = q_max.reshape(7,1)


    qdot_max = np.array([2.1750	,2.1750	,2.1750	,2.1750,	2.6100,	2.6100,	2.6100])  #TODO
    qdot_min = -1*qdot_max
    qacc_max = np.array([15,	7.5,	10	,12.5	,15	,20,	20])  #TODO
    qacc_min = -1*qacc_max

    x_pos = np.asarray(fk_franka(init_joint))  ########### initial positions

    q = init_joint
    q_prev = init_joint
      ######### delta t for which the computed velocity is commanded to the robot 3msec
    x_next = fk_franka(qdot*t + q)

    mpc_iter = 300 #TODO

    q_1 = []
    q_2 = []
    q_3 = []
    q_4 = []
    q_5 = []
    q_6 = []
    q_7 = []
    cost_tracker = []
    trajectory = []
    qdottrajc =[]
    orientResidual =[]
    #pdb.set_trace()
    solverVariable = np.hstack((qdot,x_next))
    x_min = -np.ones(3,)*np.Inf #fk_franka(q_min)
    x_max = np.ones(3,)*np.Inf #fk_franka(q_max)
    solver_minbounds= np.hstack((qdot_min , x_min))
    solver_maxbounds = np.hstack((qdot_max , x_max))
    Amat = np.hstack((np.identity(7),np.zeros((7,3)))) 
    Bmat = np.hstack((np.identity(7),np.zeros((7,3))))
    Total_time = 0
    Cmat  = np.zeros((10,10))
    Cmat[9][9] =1
    breakTime = time.time()
    for i in range(0, 4):
        print(f"mpc-itr={i}")
        orientResidual.append(orienResidual(q))
        cost_tracker.append(np.linalg.norm(x_pos - x_des))
        print("final-euclid-norm",np.linalg.norm(x_pos - x_des) , "orient-norm" , orienResidual(q) ,  " seq = " , seq)
        if np.linalg.norm(x_pos - x_des) < 0.05   and orienResidual(q) < 0.1 :
            break
            #t = 0.003
            # print("Without value velocity",v_des)

        bnds = Bounds(solver_minbounds,solver_maxbounds)
        nonlinear_constraint = NonlinearConstraint(constraintfxn , np.zeros((3,)), np.zeros((3,)) , jac= jac_constraintSympy, hess=BFGS() , )

        #linear_constraint_A = LinearConstraint(Amat*t, np.hstack((q_min-q_prev,x_min)), np.hstack((q_max-q_prev, x_max )))
        linear_constraint_A = LinearConstraint(Amat*t, q_min-q_prev, q_max-q_prev)
        #linear_constraint_B = LinearConstraint(Bmat ,np.hstack((qacc_min*t + qdotprev,x_min)), np.hstack((qacc_max*t + qdotprev,x_max)))
        linear_constraint_B = LinearConstraint(Bmat ,qacc_min*t + qdotprev, qacc_max*t + qdotprev )
        linear_constraint_C = LinearConstraint(Cmat ,0.02, np.inf )

        defaultopts={ 'maxiter': 80, 'ftol': 1e-06, 'iprint': 1, 'disp': True, 'eps': 1.4901161193847656e-08, 'finite_diff_rel_step': None}
        val = value(x_pos)
        currentTime = time.time()
        res = minimize(costfxn ,  solverVariable, args =(x_pos,val) , method='SLSQP', jac=jac_cost,
                constraints=[linear_constraint_C , nonlinear_constraint,linear_constraint_A, linear_constraint_B], options=defaultopts ,bounds=bnds)  
        timeTaken = (time.time() - currentTime)
        Total_time += timeTaken
        solverVariable = np.asarray(res['x']).squeeze()
        trajectory.append([q[0], q[1], q[2], q[3], q[4], q[5], q[6]])
        qdottrajc.append(qdotprev)
        q = q + solverVariable[0:7] * t
        x_pos =  fk_franka(q) #solverVariable[7:]  #or x_next
        solverVariable[7:] = x_pos
        qdotprev = solverVariable[0:7]
        q_prev = q
    if len(trajectory) != 0 :
        JointCost, CartCost = traj_cost(trajectory)
    
        averageTime = Total_time/(i+1)
        executionTime = (i+1)*0.02
        OrienResidual  =  orienResidual(q) 
        cart_residual = cost_tracker[-1]
        print("final-euclid-norm",np.linalg.norm(x_pos - x_des) , "orient-norm" , orienResidual(q) , "return" )
        #return JointCost, CartCost, cost_tracker, trajectory,qdottrajc,averageTime,executionTime,OrienResidual,cart_residual
        return JointCost, CartCost, cost_tracker, trajectory,qdottrajc,OrienResidual

    else:
        return 0, 0, 0 , [], 0 ,0

# %%
def plot(costResidualValue, cost_tracker , TrajectoryValue,init_joint, end_cartesian,qdottraj , plotno):
    x_fin = end_cartesian.item(0)
    y_fin = end_cartesian.item(1)
    z_fin = end_cartesian.item(2)
    pos = fk_franka(init_joint)
    # pos = init_joint
    x_init = pos[0]
    y_init = pos[1]
    z_init = pos[2]

    countValue = len(TrajectoryValue)
    xopt_solValue = np.zeros(countValue - 1)
    yopt_solValue = np.zeros(countValue - 1)
    zopt_solValue = np.zeros(countValue - 1)

    # pdb.set_trace()
    for i in range(0, countValue - 1):
        pos = fk_franka(TrajectoryValue[i])
        xopt_solValue[i] = pos[0]
        yopt_solValue[i] = pos[1]
        zopt_solValue[i] = pos[2]
    JointCostValue, CartCostValue = traj_cost(TrajectoryValue)

    fig = plt.figure(1, figsize=(12, 8), dpi=100)
    plt.title("Trajectory Plot in cartesian coordinate")
    ax = fig.add_subplot(111, projection='3d')
    leg = ax.legend()
    ax.plot(xopt_solValue, yopt_solValue, zopt_solValue, '--or', linewidth=2.0, markersize=6.0,
            label=('with Valfun; Trajcost in joint Space=', JointCostValue, 'in cart Space=',
                   CartCostValue, 'Orient_cost_residual', "{:.4f}".format(costResidualValue), 'euclid_cost_residual', "{:.4f}".format(cost_tracker[-1]) , 'itr=', len(TrajectoryValue)))
    ax.plot(x_init * np.ones(1), y_init * np.ones(1), z_init * np.ones(1), 'om', markersize=15)
    ax.plot(x_fin * np.ones(1), y_fin * np.ones(1), z_fin * np.ones(1), 'og', markersize=10)
    ax.set_xlim3d(-1.0, 1.0)
    ax.set_ylim3d(-1.0, 1.0)
    ax.set_zlim3d(-0.3, 1.2)
    ax.legend(loc='upper left', frameon=False)
    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')
    plt.savefig(f"plottraj_{plotno}__debug")
    plt.show()
    plt.close()
    fig = plt.figure(2, figsize=(12, 8), dpi=100)
    plt.title("Cost residual distance cost  VS iteration")
    plt.plot(costResidualValue, label=(
        'orient residual'))
    plt.plot(cost_tracker, label=(
        'euclid-cost residual'))
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotItr__{plotno}_debug")
    plt.show()
    plt.close()
    fig =plt.figure(3, figsize=(12, 8), dpi=100)
    plt.title("withValuefunction")
    trajct = np.asarray(TrajectoryValue)
    plt.plot(trajct[:-1, 0], '-o', linewidth=3.0, markersize=6.0 , label= ('joint1'))
    plt.plot(trajct[:-1, 1], '-o', linewidth=3.0, markersize=6.0,label= ('joint2'))
    plt.plot(trajct[:, 2], '-o', linewidth=3.0, markersize=6.0,label= ('joint3'))
    plt.plot(trajct[:, 3], '-o', linewidth=3.0, markersize=6.0,label= ('joint4'))
    plt.plot(trajct[:, 4], '-o', linewidth=3.0, markersize=6.0,label= ('joint5'))
    plt.plot(trajct[:, 5], '-o', linewidth=3.0, markersize=6.0,label= ('joint6'))
    plt.plot(trajct[:, 6], '-o', linewidth=3.0, markersize=6.0,label= ('joint7'))
    plt.title("joint angle   VS iteration")
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotjoint__{plotno}_debug")
    plt.show()
    plt.close()
    fig =plt.figure(4, figsize=(12, 8), dpi=100)
    plt.title("withValuefunction")
    trajct = np.asarray(qdottrajc)
    plt.plot(trajct[:-1, 0], '-o', linewidth=3.0, markersize=6.0 , label= ('joint1'))
    plt.plot(trajct[:-1, 1], '-o', linewidth=3.0, markersize=6.0,label= ('joint2'))
    plt.plot(trajct[:, 2], '-o', linewidth=3.0, markersize=6.0,label= ('joint3'))
    plt.plot(trajct[:, 3], '-o', linewidth=3.0, markersize=6.0,label= ('joint4'))
    plt.plot(trajct[:, 4], '-o', linewidth=3.0, markersize=6.0,label= ('joint5'))
    plt.plot(trajct[:, 5], '-o', linewidth=3.0, markersize=6.0,label= ('joint6'))
    plt.plot(trajct[:, 6], '-o', linewidth=3.0, markersize=6.0,label= ('joint7'))
    plt.title("joint-dot  VS iteration ")
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotjointdot__{plotno}_debug")
    plt.show()
    plt.close()
    return

# %%
if __name__ == "__main__":
    #init_joint =np.asarray([ 1.75890144 , -0.04687897 , 2.63947177, -1.76993654 , 0.12950717 , 0.70154342 ,0.41454053])
    #start_cart = np.asarray([-0.07702687, -0.33196785,  0.46285633])
    #end_cartesian = np.asarray([  0.16535281, -0.55448692,  0.08841983])
    #start_cart = np.asarray([ 0.89667875, -0.01707798,  0.43903176])
    init_joint =np.asarray([ -0.2828753 ,  0.82463263 , 0.39287239 , -1.1475363 ,   2.88127634 ,  2.38087392 , 2.75454838 ])

    end_pose = np.asarray([ -0.27332807,  0.27789939, -0.15650605 ])
    JointCost, CartCost, cost_tracker, trajectory,qdottrajc ,orientResidual =  trajMetricBased(init_joint , end_pose ,"alpha")
# Out:
# Start :  [ 0.80255704 -0.02318685  0.39464595]
# Goal :  [-0.27332807  0.27789939 -0.15650605]
# mpc-itr=0
# final-euclid-norm 1.2457729404542839 orient-norm 24.55258076575985 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4579229327018535
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# mpc-itr=1
# final-euclid-norm 1.24541922487923 orient-norm 24.253895148536678 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.4092429830093005
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# mpc-itr=2
# final-euclid-norm 1.2446690543618717 orient-norm 23.723024087303653 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.358674989234184
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# mpc-itr=3
# final-euclid-norm 1.2468939473042768 orient-norm 23.13231841450359 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.310234587925249
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=4
# final-euclid-norm 1.2534730514894645 orient-norm 22.588098248591898 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.252338475263175
#             Iterations: 20
#             Function evaluations: 20
#             Gradient evaluations: 20
# mpc-itr=5
# final-euclid-norm 1.2641831676782493 orient-norm 22.038668925171187 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.175266686143147
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# mpc-itr=6
# final-euclid-norm 1.278672171095482 orient-norm 21.395009315133617 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 4.083645023030184
#             Iterations: 50
#             Function evaluations: 242
#             Gradient evaluations: 46
# mpc-itr=7
# final-euclid-norm 1.296451231349196 orient-norm 20.651000027492056 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 3.9823059892255714
#             Iterations: 24
#             Function evaluations: 20
#             Gradient evaluations: 20
# mpc-itr=8
# final-euclid-norm 1.316407984279192 orient-norm 19.83808085380724 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.8690619012717846
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=9
# final-euclid-norm 1.3373808882448324 orient-norm 18.96758140177132 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.767496115785675
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# mpc-itr=10
# final-euclid-norm 1.3587312230286606 orient-norm 18.046786529458753 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.685667695546944
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# mpc-itr=11
# final-euclid-norm 1.379916465574971 orient-norm 17.091426176838276 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6122676496714883
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=12
# final-euclid-norm 1.400234877762598 orient-norm 16.13085162946949 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5766031144908483
#             Iterations: 11
#             Function evaluations: 12
#             Gradient evaluations: 11
# mpc-itr=13
# final-euclid-norm 1.4190106196186771 orient-norm 15.18135556506932 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5351312456682784
#             Iterations: 9
#             Function evaluations: 10
#             Gradient evaluations: 9
# mpc-itr=14
# final-euclid-norm 1.4353404960308973 orient-norm 14.250495692802657 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.400725341728283
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# mpc-itr=15
# final-euclid-norm 1.4486397890931115 orient-norm 13.317557779572748 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.2858170638336155
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# mpc-itr=16
# final-euclid-norm 1.4586267497315062 orient-norm 12.38083733097708 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.954155172622429
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# mpc-itr=17
# final-euclid-norm 1.465328336554677 orient-norm 11.39179275458767 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.732495550049288
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# mpc-itr=18
# final-euclid-norm 1.4690039139803035 orient-norm 10.388674302522444 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.624521009372015
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=19
# final-euclid-norm 1.4698858705959983 orient-norm 9.37649054893635 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5338084686515705
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=20
# final-euclid-norm 1.4682406669410386 orient-norm 8.362968003207905 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4591557906263968
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# mpc-itr=21
# final-euclid-norm 1.4642120956434213 orient-norm 7.368300691825559 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4983871943355775
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# mpc-itr=22
# final-euclid-norm 1.4582120863357944 orient-norm 6.413868157714195 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.9674508456426714
#             Iterations: 18
#             Function evaluations: 19
#             Gradient evaluations: 18
# mpc-itr=23
# final-euclid-norm 1.4507604465841628 orient-norm 5.5898116682415395 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3258532645502554
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# mpc-itr=24
# final-euclid-norm 1.442180135745442 orient-norm 4.876243289613662 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.498258643030803
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# mpc-itr=25
# final-euclid-norm 1.4326445349851278 orient-norm 4.254530014961097 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.6951339058782375
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=26
# final-euclid-norm 1.4223642567242303 orient-norm 3.7098593665441393 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.858355557598866
#             Iterations: 10
#             Function evaluations: 10
#             Gradient evaluations: 10
# mpc-itr=27
# final-euclid-norm 1.4115121249994218 orient-norm 3.224319502535436 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.817839487890793
#             Iterations: 10
#             Function evaluations: 10
#             Gradient evaluations: 10
# mpc-itr=28
# final-euclid-norm 1.4001326593009804 orient-norm 2.788128068341147 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.5952685974765672
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# mpc-itr=29
# final-euclid-norm 1.3882082538917937 orient-norm 2.395062795445994 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.1894189045681385
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# mpc-itr=30
# final-euclid-norm 1.3760573746177471 orient-norm 2.0561624831876717 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.7686489449778495
#             Iterations: 13
#             Function evaluations: 14
#             Gradient evaluations: 13
# mpc-itr=31
# final-euclid-norm 1.3635794102736978 orient-norm 1.7662178795876247 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.5104003188737214
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=32
# final-euclid-norm 1.3510293108132074 orient-norm 1.5375172048480734 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.3045375743648338
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# mpc-itr=33
# final-euclid-norm 1.3383400205745277 orient-norm 1.3665403165752272 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.14155111441447
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# mpc-itr=34
# final-euclid-norm 1.3254412212749793 orient-norm 1.251118372867802 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.9989782847166468
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# mpc-itr=35
# final-euclid-norm 1.3131316656108263 orient-norm 1.1847729145270496 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8690377154502797
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# mpc-itr=36
# final-euclid-norm 1.3014949206724054 orient-norm 1.1623317766325987 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7626912659086011
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# mpc-itr=37
# final-euclid-norm 1.29060210231711 orient-norm 1.1805667829960116 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6577989300469678
#             Iterations: 20
#             Function evaluations: 21
#             Gradient evaluations: 20
# mpc-itr=38
# final-euclid-norm 1.2809923513192152 orient-norm 1.2273268586149182 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5702594162723265
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=39
# final-euclid-norm 1.2724778315806586 orient-norm 1.2799966469215767 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5061421077245694
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# mpc-itr=40
# final-euclid-norm 1.264691336579398 orient-norm 1.3236183824683898 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4751658118054083
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# mpc-itr=41
# final-euclid-norm 1.2587083757441957 orient-norm 1.3392315021439574 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.4730031336934615
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# mpc-itr=42
# final-euclid-norm 1.2548894695030068 orient-norm 1.3252999568531365 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5139248902023719
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# mpc-itr=43
# final-euclid-norm 1.251912704745264 orient-norm 1.2985877872964902 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.565436940152593
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# mpc-itr=44
# final-euclid-norm 1.2494884100465518 orient-norm 1.2576131452680972 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.6320331383325932
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=45
# final-euclid-norm 1.2468322307357036 orient-norm 1.20943072529779 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.7221245605308728
#             Iterations: 15
#             Function evaluations: 16
#             Gradient evaluations: 15
# mpc-itr=46
# final-euclid-norm 1.2419248260542155 orient-norm 1.1732471532142577 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.845603410181259
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=47
# final-euclid-norm 1.2341900400466586 orient-norm 1.142388559520878 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0022819625906454
#             Iterations: 18
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=48
# final-euclid-norm 1.2230351894336116 orient-norm 1.1111204866445272 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1879304462240383
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=49
# final-euclid-norm 1.2079569614719252 orient-norm 1.071269540542415 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2026568804222784
#             Iterations: 19
#             Function evaluations: 20
#             Gradient evaluations: 19
# mpc-itr=50
# final-euclid-norm 1.189882551495927 orient-norm 0.9834568329974642 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2071118561415117
#             Iterations: 15
#             Function evaluations: 16
#             Gradient evaluations: 15
# mpc-itr=51
# final-euclid-norm 1.1710212336318897 orient-norm 0.8574732486396929 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.2434561326798472
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=52
# final-euclid-norm 1.1508701567750337 orient-norm 0.7458043735442832 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.1179696018789707
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# mpc-itr=53
# final-euclid-norm 1.1292426555675041 orient-norm 0.7121141154221248 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.952125215752464
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# mpc-itr=54
# final-euclid-norm 1.1039384414141107 orient-norm 29.258941760293883 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4.952361046227419
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# mpc-itr=55
# final-euclid-norm 1.0759148288594316 orient-norm 27.72696964606062 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.772311226282177
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# mpc-itr=56
# final-euclid-norm 1.0457559939296175 orient-norm 17.39966854698111 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.4871513610893246
#             Iterations: 9
#             Function evaluations: 9
#             Gradient evaluations: 9
# mpc-itr=57
# final-euclid-norm 1.0134448428395528 orient-norm 14.914344058284998 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.3164830574128583
#             Iterations: 8
#             Function evaluations: 9
#             Gradient evaluations: 8
# mpc-itr=58
# final-euclid-norm 0.9789976585704375 orient-norm 13.337949421547755 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.169117613166877
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=59
# final-euclid-norm 0.9424785907576112 orient-norm 12.045406480962225 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3.006650870958449
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# mpc-itr=60
# final-euclid-norm 0.9040162719874395 orient-norm 10.873174769814025 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.8412062954762733
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# mpc-itr=61
# final-euclid-norm 0.8641732944247158 orient-norm 9.781096298684119 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.664793391191264
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# mpc-itr=62
# final-euclid-norm 0.8240611920013099 orient-norm 8.742215123262195 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.4831637004572977
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# mpc-itr=63
# final-euclid-norm 0.7841626976532569 orient-norm 7.737172734175527 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.302048796417911
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# mpc-itr=64
# final-euclid-norm 0.7454859238835052 orient-norm 6.778659518674793 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 2.2229866971152674
#             Iterations: 19
#             Function evaluations: 53
#             Gradient evaluations: 15
# mpc-itr=65
# final-euclid-norm 0.7081157279871204 orient-norm 5.903045140014386 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 2.0769634041626603
#             Iterations: 15
#             Function evaluations: 21
#             Gradient evaluations: 11
# mpc-itr=66
# final-euclid-norm 0.6724822305184089 orient-norm 5.119740496664329 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.9262140661590346
#             Iterations: 13
#             Function evaluations: 9
#             Gradient evaluations: 9
# mpc-itr=67
# final-euclid-norm 0.638629571388909 orient-norm 4.406660378175857 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.7789498100103964
#             Iterations: 14
#             Function evaluations: 20
#             Gradient evaluations: 10
# mpc-itr=68
# final-euclid-norm 0.6065712879629972 orient-norm 3.7502356355718 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.642186236293236
#             Iterations: 22
#             Function evaluations: 78
#             Gradient evaluations: 18
# mpc-itr=69
# final-euclid-norm 0.5763027405807221 orient-norm 3.1426962879638154 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.5151859943227386
#             Iterations: 18
#             Function evaluations: 41
#             Gradient evaluations: 14
# mpc-itr=70
# final-euclid-norm 0.5462196921450321 orient-norm 2.597811800071714 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.396373035971874
#             Iterations: 16
#             Function evaluations: 22
#             Gradient evaluations: 12
# mpc-itr=71
# final-euclid-norm 0.5164503268607726 orient-norm 2.1173686132046114 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.27495234686138
#             Iterations: 14
#             Function evaluations: 10
#             Gradient evaluations: 10
# mpc-itr=72
# final-euclid-norm 0.48705250731298216 orient-norm 1.7107350078433372 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.1772162633817698
#             Iterations: 20
#             Function evaluations: 75
#             Gradient evaluations: 16
# mpc-itr=73
# final-euclid-norm 0.45838048953849936 orient-norm 1.375394063162242 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.1008086169879592
#             Iterations: 22
#             Function evaluations: 86
#             Gradient evaluations: 18
# mpc-itr=74
# final-euclid-norm 0.43077701255112344 orient-norm 1.1082409778152003 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.039828756760179
#             Iterations: 26
#             Function evaluations: 75
#             Gradient evaluations: 22
# mpc-itr=75
# final-euclid-norm 0.4043446906640092 orient-norm 0.9027087563140473 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.9930680626744433
#             Iterations: 27
#             Function evaluations: 73
#             Gradient evaluations: 23
# mpc-itr=76
# final-euclid-norm 0.37894496569140795 orient-norm 0.7539235074009716 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.9510304263136389
#             Iterations: 30
#             Function evaluations: 106
#             Gradient evaluations: 26
# mpc-itr=77
# final-euclid-norm 0.35489759379565444 orient-norm 0.6484155700408525 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.8938667413438177
#             Iterations: 35
#             Function evaluations: 121
#             Gradient evaluations: 31
# mpc-itr=78
# final-euclid-norm 0.3330492432382463 orient-norm 0.573584519901997 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.8350762458723883
#             Iterations: 24
#             Function evaluations: 30
#             Gradient evaluations: 20
# mpc-itr=79
# final-euclid-norm 0.31391906720204243 orient-norm 0.5228533003219411 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.787377752455195
#             Iterations: 25
#             Function evaluations: 41
#             Gradient evaluations: 21
# mpc-itr=80
# final-euclid-norm 0.2990735033080317 orient-norm 0.4897703218437578 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.7522266755792895
#             Iterations: 22
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=81
# final-euclid-norm 0.28745038722185856 orient-norm 0.46943139479881607 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.7292567979216058
#             Iterations: 23
#             Function evaluations: 29
#             Gradient evaluations: 19
# mpc-itr=82
# final-euclid-norm 0.27790938428325423 orient-norm 0.4573483453670563 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.7154940688509192
#             Iterations: 25
#             Function evaluations: 31
#             Gradient evaluations: 21
# mpc-itr=83
# final-euclid-norm 0.2694253718053541 orient-norm 0.45040671660840115 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.7015761660512827
#             Iterations: 23
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=84
# final-euclid-norm 0.26120721965703514 orient-norm 0.44618281918825276 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.6871393310516782
#             Iterations: 28
#             Function evaluations: 42
#             Gradient evaluations: 24
# mpc-itr=85
# final-euclid-norm 0.25268866460438394 orient-norm 0.44096697489170017 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.668678458885193
#             Iterations: 25
#             Function evaluations: 41
#             Gradient evaluations: 21
# mpc-itr=86
# final-euclid-norm 0.24366655765344875 orient-norm 0.42717834099345825 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.6367737961064686
#             Iterations: 26
#             Function evaluations: 48
#             Gradient evaluations: 22
# mpc-itr=87
# final-euclid-norm 0.23376282906826268 orient-norm 0.4035057497313602 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5704476980056971
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# mpc-itr=88
# final-euclid-norm 0.2229812985559102 orient-norm 0.3619761253659757 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5212543212577264
#             Iterations: 19
#             Function evaluations: 19
#             Gradient evaluations: 19
# mpc-itr=89
# final-euclid-norm 0.21134468344371288 orient-norm 0.3095122866231822 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4689713311740292
#             Iterations: 21
#             Function evaluations: 22
#             Gradient evaluations: 21
# mpc-itr=90
# final-euclid-norm 0.19938840242937073 orient-norm 0.254247674700637 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.418008173337184
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# mpc-itr=91
# final-euclid-norm 0.187966296998508 orient-norm 0.2031271721695161 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.37301757935647634
#             Iterations: 16
#             Function evaluations: 16
#             Gradient evaluations: 16
# mpc-itr=92
# final-euclid-norm 0.1777447204003272 orient-norm 0.16380444140917366 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.35629233518728015
#             Iterations: 36
#             Function evaluations: 122
#             Gradient evaluations: 32
# mpc-itr=93
# final-euclid-norm 0.1702343261710352 orient-norm 0.13375307352650112 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.32046292822896216
#             Iterations: 28
#             Function evaluations: 24
#             Gradient evaluations: 24
# mpc-itr=94
# final-euclid-norm 0.16496974496030928 orient-norm 0.11042737012513588 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.28979185221797243
#             Iterations: 30
#             Function evaluations: 41
#             Gradient evaluations: 26
# mpc-itr=95
# final-euclid-norm 0.161607312546032 orient-norm 0.09196374470749676 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.16356173125190163
#             Iterations: 27
#             Function evaluations: 33
#             Gradient evaluations: 23
# mpc-itr=96
# final-euclid-norm 0.15751951335935957 orient-norm 0.08265452027775375 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.15555350930818002
#             Iterations: 30
#             Function evaluations: 47
#             Gradient evaluations: 26
# mpc-itr=97
# final-euclid-norm 0.1535506008917684 orient-norm 0.07873238403498947 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.14792581225463908
#             Iterations: 32
#             Function evaluations: 66
#             Gradient evaluations: 28
# mpc-itr=98
# final-euclid-norm 0.15014989264255008 orient-norm 0.0772348974802036 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.14130262584648046
#             Iterations: 31
#             Function evaluations: 86
#             Gradient evaluations: 27
# mpc-itr=99
# final-euclid-norm 0.14714666483002276 orient-norm 0.07741782148005608 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.13656073672548547
#             Iterations: 31
#             Function evaluations: 77
#             Gradient evaluations: 27
# mpc-itr=100
# final-euclid-norm 0.14429713426735805 orient-norm 0.07905739851027889 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.13318172400421563
#             Iterations: 33
#             Function evaluations: 98
#             Gradient evaluations: 29
# mpc-itr=101
# final-euclid-norm 0.14140273403021034 orient-norm 0.08346451326798475 seq= alpha
# Iteration limit reached    (Exit mode 9)
#             Current function value: 0.27464302542792096
#             Iterations: 80
#             Function evaluations: 479
#             Gradient evaluations: 80
# mpc-itr=102
# final-euclid-norm 0.13849968562926226 orient-norm 0.09000043457950452 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.28695618816955104
#             Iterations: 22
#             Function evaluations: 18
#             Gradient evaluations: 18
# mpc-itr=103
# final-euclid-norm 0.1363283035597676 orient-norm 0.09471096278679404 seq= alpha
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.29984467197220954
#             Iterations: 63
#             Function evaluations: 393
#             Gradient evaluations: 59
# mpc-itr=104
# final-euclid-norm 0.13550201807062523 orient-norm 0.09942195065329401 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29735860812886017
#             Iterations: 24
#             Function evaluations: 24
#             Gradient evaluations: 24
# mpc-itr=105
# final-euclid-norm 0.13573744013834949 orient-norm 0.09749895609946552 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.28703147641252114
#             Iterations: 17
#             Function evaluations: 18
#             Gradient evaluations: 17
# mpc-itr=106
# final-euclid-norm 0.13582434828729398 orient-norm 0.0914952523524803 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.12240090263368332
#             Iterations: 18
#             Function evaluations: 56
#             Gradient evaluations: 18
# mpc-itr=107
# final-euclid-norm 0.13292352002496524 orient-norm 0.0899999766646965 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2710841641523744
#             Iterations: 54
#             Function evaluations: 367
#             Gradient evaluations: 54
# mpc-itr=108
# final-euclid-norm 0.12827112547454028 orient-norm 0.09001181818942534 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.27190879236209964
#             Iterations: 63
#             Function evaluations: 334
#             Gradient evaluations: 63
# mpc-itr=109
# final-euclid-norm 0.12310537037629805 orient-norm 0.09005953558244383 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.275199526865345
#             Iterations: 54
#             Function evaluations: 265
#             Gradient evaluations: 54
# mpc-itr=110
# final-euclid-norm 0.11716419040416032 orient-norm 0.09003438492237273 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.28367009538372695
#             Iterations: 79
#             Function evaluations: 404
#             Gradient evaluations: 79
# mpc-itr=111
# final-euclid-norm 0.11013574676449324 orient-norm 0.09001901759170627 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.30020063499228455
#             Iterations: 51
#             Function evaluations: 282
#             Gradient evaluations: 51
# mpc-itr=112
# final-euclid-norm 0.10222601947714086 orient-norm 0.09000450175467148 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3278365509776204
#             Iterations: 39
#             Function evaluations: 215
#             Gradient evaluations: 39
# mpc-itr=113
# final-euclid-norm 0.09564194822292055 orient-norm 0.09000000005434111 seq= alpha
# Iteration limit reached    (Exit mode 9)
#             Current function value: 0.3625005649687448
#             Iterations: 80
#             Function evaluations: 380
#             Gradient evaluations: 80
# mpc-itr=114
# final-euclid-norm 0.09070303205019206 orient-norm 0.09000256472205977 seq= alpha
# Iteration limit reached    (Exit mode 9)
#             Current function value: 0.39091366108613207
#             Iterations: 80
#             Function evaluations: 467
#             Gradient evaluations: 80
# mpc-itr=115
# final-euclid-norm 0.08726731454366551 orient-norm 0.09000595112961929 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4127450377065523
#             Iterations: 62
#             Function evaluations: 359
#             Gradient evaluations: 62
# mpc-itr=116
# final-euclid-norm 0.08483634327971235 orient-norm 0.09000997046993864 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.42963913235095463
#             Iterations: 52
#             Function evaluations: 271
#             Gradient evaluations: 52
# mpc-itr=117
# final-euclid-norm 0.0814535638052495 orient-norm 0.09000889187511073 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.45830738280563277
#             Iterations: 32
#             Function evaluations: 182
#             Gradient evaluations: 32
# mpc-itr=118
# final-euclid-norm 0.07820722799409821 orient-norm 0.0900040919031042 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4899895577367427
#             Iterations: 66
#             Function evaluations: 421
#             Gradient evaluations: 66
# mpc-itr=119
# final-euclid-norm 0.07509675169381465 orient-norm 0.09000164251348687 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5249508926849805
#             Iterations: 53
#             Function evaluations: 312
#             Gradient evaluations: 53
# mpc-itr=120
# final-euclid-norm 0.07270982393275692 orient-norm 0.09000067326617783 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5552773132447771
#             Iterations: 50
#             Function evaluations: 285
#             Gradient evaluations: 50
# mpc-itr=121
# final-euclid-norm 0.07152374097602063 orient-norm 0.09001131165153528 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5698850689473108
#             Iterations: 47
#             Function evaluations: 273
#             Gradient evaluations: 47
# mpc-itr=122
# final-euclid-norm 0.07029464253350717 orient-norm 0.09000175253441392 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5858307771233539
#             Iterations: 56
#             Function evaluations: 309
#             Gradient evaluations: 56
# mpc-itr=123
# final-euclid-norm 0.06920299669962565 orient-norm 0.09000017972291487 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6006403803047403
#             Iterations: 49
#             Function evaluations: 280
#             Gradient evaluations: 49
# mpc-itr=124
# final-euclid-norm 0.06827566561030285 orient-norm 0.09000034710557367 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6134669385704294
#             Iterations: 54
#             Function evaluations: 288
#             Gradient evaluations: 54
# mpc-itr=125
# final-euclid-norm 0.06751442583863089 orient-norm 0.09000059267100362 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6240216788843833
#             Iterations: 26
#             Function evaluations: 116
#             Gradient evaluations: 26
# mpc-itr=126
# final-euclid-norm 0.06689221420401156 orient-norm 0.09000070089300798 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.632511460478977
#             Iterations: 63
#             Function evaluations: 398
#             Gradient evaluations: 63
# mpc-itr=127
# final-euclid-norm 0.06639795098294612 orient-norm 0.09000072937497071 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6391059081129807
#             Iterations: 58
#             Function evaluations: 311
#             Gradient evaluations: 58
# mpc-itr=128
# final-euclid-norm 0.06603160072171092 orient-norm 0.09000047332899894 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6439531181048259
#             Iterations: 55
#             Function evaluations: 304
#             Gradient evaluations: 55
# mpc-itr=129
# final-euclid-norm 0.06572391204224518 orient-norm 0.09000044955460942 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6478525583322036
#             Iterations: 57
#             Function evaluations: 339
#             Gradient evaluations: 57
# mpc-itr=130
# final-euclid-norm 0.06547071966185242 orient-norm 0.09000038598460491 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6509402207563254
#             Iterations: 54
#             Function evaluations: 292
#             Gradient evaluations: 54
# mpc-itr=131
# final-euclid-norm 0.06526287391826412 orient-norm 0.09000029030178794 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6533979313667434
#             Iterations: 48
#             Function evaluations: 308
#             Gradient evaluations: 48
# mpc-itr=132
# final-euclid-norm 0.06507148350677049 orient-norm 0.09000000004583726 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6555530171274916
#             Iterations: 69
#             Function evaluations: 416
#             Gradient evaluations: 69
# mpc-itr=133
# final-euclid-norm 0.06492397803889424 orient-norm 0.09000036734357209 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6572089464005343
#             Iterations: 52
#             Function evaluations: 296
#             Gradient evaluations: 52
# mpc-itr=134
# final-euclid-norm 0.06478758903359269 orient-norm 0.09000000005741125 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6586649602224321
#             Iterations: 53
#             Function evaluations: 276
#             Gradient evaluations: 53
# mpc-itr=135
# final-euclid-norm 0.06468288346788267 orient-norm 0.0900002780517285 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6598099358054655
#             Iterations: 58
#             Function evaluations: 342
#             Gradient evaluations: 58
# mpc-itr=136
# final-euclid-norm 0.06459627858861249 orient-norm 0.09000012069679905 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6607568100813852
#             Iterations: 57
#             Function evaluations: 360
#             Gradient evaluations: 57
# mpc-itr=137
# final-euclid-norm 0.0645118952390968 orient-norm 0.0900000315444828 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6616249010421564
#             Iterations: 58
#             Function evaluations: 363
#             Gradient evaluations: 58
# mpc-itr=138
# final-euclid-norm 0.06444275450262461 orient-norm 0.09000004571345298 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6623322012291348
#             Iterations: 53
#             Function evaluations: 305
#             Gradient evaluations: 53
# mpc-itr=139
# final-euclid-norm 0.06439281383708828 orient-norm 0.09000000180423755 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6628897473322087
#             Iterations: 48
#             Function evaluations: 301
#             Gradient evaluations: 48
# mpc-itr=140
# final-euclid-norm 0.06434463568648568 orient-norm 0.09000000582242575 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6634056464116972
#             Iterations: 55
#             Function evaluations: 345
#             Gradient evaluations: 55
# mpc-itr=141
# final-euclid-norm 0.06429871560931033 orient-norm 0.09000000968227523 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6638744060236168
#             Iterations: 60
#             Function evaluations: 352
#             Gradient evaluations: 60
# mpc-itr=142
# final-euclid-norm 0.06425689934323478 orient-norm 0.09000001423609574 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6642846027805925
#             Iterations: 54
#             Function evaluations: 321
#             Gradient evaluations: 54
# mpc-itr=143
# final-euclid-norm 0.06422472783695078 orient-norm 0.09000001261058743 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6646104289246256
#             Iterations: 68
#             Function evaluations: 459
#             Gradient evaluations: 68
# mpc-itr=144
# final-euclid-norm 0.06419608965133473 orient-norm 0.09000000000084016 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6649063615812599
#             Iterations: 61
#             Function evaluations: 375
#             Gradient evaluations: 61
# mpc-itr=145
# final-euclid-norm 0.06416918429666425 orient-norm 0.09000000724621376 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6651730840858471
#             Iterations: 63
#             Function evaluations: 400
#             Gradient evaluations: 63
# mpc-itr=146
# final-euclid-norm 0.06414428751272482 orient-norm 0.09000000868570117 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6654097280698776
#             Iterations: 63
#             Function evaluations: 396
#             Gradient evaluations: 63
# mpc-itr=147
# final-euclid-norm 0.06412197138592912 orient-norm 0.09000000943983813 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6656153383018417
#             Iterations: 60
#             Function evaluations: 357
#             Gradient evaluations: 60
# mpc-itr=148
# final-euclid-norm 0.0641028955853677 orient-norm 0.09000000862599397 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6657899347702071
#             Iterations: 56
#             Function evaluations: 344
#             Gradient evaluations: 56
# mpc-itr=149
# final-euclid-norm 0.06408704535023173 orient-norm 0.09000000000074605 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6659448983050014
#             Iterations: 63
#             Function evaluations: 388
#             Gradient evaluations: 63
# mpc-itr=150
# final-euclid-norm 0.06407235545897132 orient-norm 0.09000000787688223 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6660821440349267
#             Iterations: 59
#             Function evaluations: 353
#             Gradient evaluations: 59
# mpc-itr=151
# final-euclid-norm 0.06405892878181967 orient-norm 0.09000000755254528 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6662025686867189
#             Iterations: 61
#             Function evaluations: 382
#             Gradient evaluations: 61
# mpc-itr=152
# final-euclid-norm 0.06404693708124601 orient-norm 0.09000000687564397 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6663073134980071
#             Iterations: 56
#             Function evaluations: 328
#             Gradient evaluations: 56
# mpc-itr=153
# final-euclid-norm 0.06403653823455081 orient-norm 0.09000000594123053 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6663975896409876
#             Iterations: 52
#             Function evaluations: 321
#             Gradient evaluations: 52
# mpc-itr=154
# final-euclid-norm 0.06402905079305958 orient-norm 0.09000000000179237 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6664746601363499
#             Iterations: 55
#             Function evaluations: 313
#             Gradient evaluations: 55
# mpc-itr=155
# final-euclid-norm 0.06402230417989986 orient-norm 0.09000000445874859 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6665426731903195
#             Iterations: 48
#             Function evaluations: 271
#             Gradient evaluations: 48
# mpc-itr=156
# final-euclid-norm 0.064016009803916 orient-norm 0.09000000507877426 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6666029532128627
#             Iterations: 54
#             Function evaluations: 338
#             Gradient evaluations: 54
# mpc-itr=157
# final-euclid-norm 0.06401010408160175 orient-norm 0.09000000506466496 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6666564776441898
#             Iterations: 59
#             Function evaluations: 366
#             Gradient evaluations: 59
# mpc-itr=158
# final-euclid-norm 0.06400466257778652 orient-norm 0.0900000046691297 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6667037479462941
#             Iterations: 54
#             Function evaluations: 321
#             Gradient evaluations: 54
# mpc-itr=159
# final-euclid-norm 0.0639998036064305 orient-norm 0.0900000041550998 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.666745098114101
#             Iterations: 61
#             Function evaluations: 403
#             Gradient evaluations: 61
# mpc-itr=160
# final-euclid-norm 0.06399560271960494 orient-norm 0.09000000377695977 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6667809148558705
#             Iterations: 49
#             Function evaluations: 285
#             Gradient evaluations: 49
# mpc-itr=161
# final-euclid-norm 0.0639921031804587 orient-norm 0.09000000345950596 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.666811624745928
#             Iterations: 49
#             Function evaluations: 272
#             Gradient evaluations: 49
# mpc-itr=162
# final-euclid-norm 0.0639892784651075 orient-norm 0.09000000332073202 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.666837768600928
#             Iterations: 59
#             Function evaluations: 397
#             Gradient evaluations: 59
# mpc-itr=163
# final-euclid-norm 0.06398705956843632 orient-norm 0.09000000329074331 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6668599259879009
#             Iterations: 55
#             Function evaluations: 344
#             Gradient evaluations: 55
# mpc-itr=164
# final-euclid-norm 0.06398537698138464 orient-norm 0.09000000324834598 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6668786268666035
#             Iterations: 50
#             Function evaluations: 291
#             Gradient evaluations: 50
# mpc-itr=165
# final-euclid-norm 0.06398415445266582 orient-norm 0.09000000322520642 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6668943672195791
#             Iterations: 52
#             Function evaluations: 309
#             Gradient evaluations: 52
# mpc-itr=166
# final-euclid-norm 0.06398331361296589 orient-norm 0.09000000322426871 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669075992335123
#             Iterations: 56
#             Function evaluations: 364
#             Gradient evaluations: 56
# mpc-itr=167
# final-euclid-norm 0.0639827877350889 orient-norm 0.09000000320887094 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669187076192393
#             Iterations: 48
#             Function evaluations: 272
#             Gradient evaluations: 48
# mpc-itr=168
# final-euclid-norm 0.06398253107440058 orient-norm 0.09000000314090136 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.666927996104007
#             Iterations: 55
#             Function evaluations: 338
#             Gradient evaluations: 55
# mpc-itr=169
# final-euclid-norm 0.06398249433274443 orient-norm 0.09000000311161366 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669357457162134
#             Iterations: 53
#             Function evaluations: 315
#             Gradient evaluations: 53
# mpc-itr=170
# final-euclid-norm 0.0639826447884036 orient-norm 0.0900000030437553 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669421729360022
#             Iterations: 51
#             Function evaluations: 312
#             Gradient evaluations: 51
# mpc-itr=171
# final-euclid-norm 0.06398295294518179 orient-norm 0.09000000297895536 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669474663620871
#             Iterations: 59
#             Function evaluations: 355
#             Gradient evaluations: 59
# mpc-itr=172
# final-euclid-norm 0.06398338719877801 orient-norm 0.09000000294222056 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669517999187196
#             Iterations: 57
#             Function evaluations: 330
#             Gradient evaluations: 57
# mpc-itr=173
# final-euclid-norm 0.06398392584312443 orient-norm 0.09000000287931981 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669553088258375
#             Iterations: 55
#             Function evaluations: 329
#             Gradient evaluations: 55
# mpc-itr=174
# final-euclid-norm 0.06398454691073115 orient-norm 0.09000000282603628 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669581165861963
#             Iterations: 53
#             Function evaluations: 300
#             Gradient evaluations: 53
# mpc-itr=175
# final-euclid-norm 0.06398522877057528 orient-norm 0.0900000027805247 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669603339299277
#             Iterations: 65
#             Function evaluations: 415
#             Gradient evaluations: 65
# mpc-itr=176
# final-euclid-norm 0.06398594743491402 orient-norm 0.0900000027670876 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669620682653482
#             Iterations: 44
#             Function evaluations: 238
#             Gradient evaluations: 44
# mpc-itr=177
# final-euclid-norm 0.06398669312187971 orient-norm 0.09000000268571429 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669633839562846
#             Iterations: 47
#             Function evaluations: 269
#             Gradient evaluations: 47
# mpc-itr=178
# final-euclid-norm 0.06398744562498478 orient-norm 0.09000000266844588 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669643666423639
#             Iterations: 47
#             Function evaluations: 274
#             Gradient evaluations: 47
# mpc-itr=179
# final-euclid-norm 0.06398819036504809 orient-norm 0.09000000264248934 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669650809443304
#             Iterations: 52
#             Function evaluations: 297
#             Gradient evaluations: 52
# mpc-itr=180
# final-euclid-norm 0.06398891552590187 orient-norm 0.09000000262366148 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669655826750666
#             Iterations: 59
#             Function evaluations: 363
#             Gradient evaluations: 59
# mpc-itr=181
# final-euclid-norm 0.06398961343720319 orient-norm 0.09000000260434673 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669659145479454
#             Iterations: 57
#             Function evaluations: 358
#             Gradient evaluations: 57
# mpc-itr=182
# final-euclid-norm 0.06399028069740843 orient-norm 0.09000000256898276 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669661057422245
#             Iterations: 61
#             Function evaluations: 375
#             Gradient evaluations: 61
# mpc-itr=183
# final-euclid-norm 0.06399091343981236 orient-norm 0.09000000254730375 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669661850618966
#             Iterations: 56
#             Function evaluations: 323
#             Gradient evaluations: 56
# mpc-itr=184
# final-euclid-norm 0.063991509470236 orient-norm 0.09000000251466941 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.666966173745854
#             Iterations: 61
#             Function evaluations: 385
#             Gradient evaluations: 61
# mpc-itr=185
# final-euclid-norm 0.06399206544233764 orient-norm 0.09000000250228003 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669660956380139
#             Iterations: 54
#             Function evaluations: 311
#             Gradient evaluations: 54
# mpc-itr=186
# final-euclid-norm 0.06399257982342837 orient-norm 0.09000000247368109 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669659667186485
#             Iterations: 47
#             Function evaluations: 247
#             Gradient evaluations: 47
# mpc-itr=187
# final-euclid-norm 0.06399305051301583 orient-norm 0.09000000245076176 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669658040310665
#             Iterations: 63
#             Function evaluations: 391
#             Gradient evaluations: 63
# mpc-itr=188
# final-euclid-norm 0.06399347576831942 orient-norm 0.09000000246116452 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669656254657645
#             Iterations: 59
#             Function evaluations: 343
#             Gradient evaluations: 59
# mpc-itr=189
# final-euclid-norm 0.06399385707408795 orient-norm 0.0900000024396501 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669654368916278
#             Iterations: 52
#             Function evaluations: 296
#             Gradient evaluations: 52
# mpc-itr=190
# final-euclid-norm 0.06399419572374448 orient-norm 0.09000000241718997 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669652449777946
#             Iterations: 59
#             Function evaluations: 346
#             Gradient evaluations: 59
# mpc-itr=191
# final-euclid-norm 0.0639944932158698 orient-norm 0.09000000241597793 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669650568133983
#             Iterations: 64
#             Function evaluations: 374
#             Gradient evaluations: 64
# mpc-itr=192
# final-euclid-norm 0.06399475220824175 orient-norm 0.09000000241062175 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669648750288573
#             Iterations: 47
#             Function evaluations: 240
#             Gradient evaluations: 47
# mpc-itr=193
# final-euclid-norm 0.06399497456571776 orient-norm 0.09000000237899416 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669647009974581
#             Iterations: 55
#             Function evaluations: 317
#             Gradient evaluations: 55
# mpc-itr=194
# final-euclid-norm 0.06399516225565444 orient-norm 0.0900000023838238 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669645397747769
#             Iterations: 50
#             Function evaluations: 263
#             Gradient evaluations: 50
# mpc-itr=195
# final-euclid-norm 0.06399531736393359 orient-norm 0.09000000237102194 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669643924144821
#             Iterations: 66
#             Function evaluations: 415
#             Gradient evaluations: 66
# mpc-itr=196
# final-euclid-norm 0.06399544348514105 orient-norm 0.09000000238422996 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669642599190717
#             Iterations: 53
#             Function evaluations: 275
#             Gradient evaluations: 53
# mpc-itr=197
# final-euclid-norm 0.06399554315388677 orient-norm 0.09000000236042814 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669641401303813
#             Iterations: 68
#             Function evaluations: 426
#             Gradient evaluations: 68
# mpc-itr=198
# final-euclid-norm 0.06399562022338944 orient-norm 0.09000000237268528 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669640328409069
#             Iterations: 64
#             Function evaluations: 392
#             Gradient evaluations: 64
# mpc-itr=199
# final-euclid-norm 0.06399567762738669 orient-norm 0.09000000236071369 seq= alpha
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6669639348298679
#             Iterations: 42
#             Function evaluations: 235
#             Gradient evaluations: 42
# final-euclid-norm 0.06399571563181729 orient-norm 0.09000000233064144

# %%
    /*vector<double> currentq({ -0.2828753 ,  0.82463263 , 0.39287239 , -1.1475363 ,   2.88127634 ,  2.38087392 , 2.75454838 });
    vector<double> current_cartpos({0.89667875, -0.01707798,  0.43903176});
    vector<double> goalpos({ -0.27332807,  0.27789939, -0.15650605});*/



trajc = np.reshape(trajectory,(len(trajectory) , 7))

# %%
np.save( " metric_ik" , trajectory)

# %%
c
# Out:
# [0.8025570361295796,
#  -0.023186854099298826,
#  0.3946459537075372,
#  0.6534950788325075,
#  -1.0401702259196066,
#  2.4803621957517055]

# %%
costResidualValue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f7b1dd9c205e> in <module>()
# ----> 1 costResidualValue
#
# NameError: name 'costResidualValue' is not defined

# %%
 plot(costResidualValue, cost_tracker , TrajectoryValue,init_joint, end_pose,qdottraj , plotno):
# Out:
# (400, 7)

# %%
plot(orientResidual,cost_tracker, trajectory ,init_joint, end_cartesian ,qdottrajc, "1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d226a8a6bea3> in <module>
# ----> 1 plot(orientResidual,cost_tracker, trajectory ,init_joint, end_cartesian ,qdottrajc, "1")
#
# NameError: name 'end_cartesian' is not defined

# %% [markdown]
# # New Section

# %%
start_cart = np.asarray(fk_franka(init_joint))

# %%
start_cart
# Out:
# array([ 0.80255704, -0.02318685,  0.39464595])
