# %%
import roboticstoolbox as rtb
import cvxopt

import autograd.numpy as np
import pdb
import cvxopt
from cvxopt import solvers
import random
import  matplotlib.pyplot as plt
from spatialmath import SE3
import torch
from autograd import grad
import gc
import jax
import jax.numpy as jnp
import numpy as np
from jax import jit, vmap, random
import numpy as np

# %%
def fk_frankatraj(q):
    q_1 = q[0]
    q_2 = q[1]
    q_3 = q[2]
    q_4 = q[3]
    q_5 = q[4]
    q_6 = q[5]
    q_7 = q[0]
    x = -0.107*(((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1))*jnp.cos(q_5) + (jnp.sin(q_1)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1)*jnp.cos(q_2))*jnp.sin(q_5))*jnp.sin(q_6) - 0.088*(((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1))*jnp.cos(q_5) + (jnp.sin(q_1)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1)*jnp.cos(q_2))*jnp.sin(q_5))*jnp.cos(q_6) + 0.088*((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4))*jnp.sin(q_6) - 0.107*((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4))*jnp.cos(q_6) + 0.384*(jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + 0.0825*(jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - 0.0825*jnp.sin(q_1)*jnp.sin(q_3) - 0.0825*jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1) + 0.384*jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4) + 0.316*jnp.sin(q_2)*jnp.cos(q_1) + 0.0825*jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3)

    y = 0.107*(((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) + jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4))*jnp.cos(q_5) - (jnp.sin(q_1)*jnp.sin(q_3)*jnp.cos(q_2) - jnp.cos(q_1)*jnp.cos(q_3))*jnp.sin(q_5))*jnp.sin(q_6) + 0.088*(((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) + jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4))*jnp.cos(q_5) - (jnp.sin(q_1)*jnp.sin(q_3)*jnp.cos(q_2) - jnp.cos(q_1)*jnp.cos(q_3))*jnp.sin(q_5))*jnp.cos(q_6) - 0.088*((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4))*jnp.sin(q_6) + 0.107*((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4))*jnp.cos(q_6) - 0.384*(jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - 0.0825*(jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) - 0.0825*jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4) + 0.384*jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4) + 0.316*jnp.sin(q_1)*jnp.sin(q_2) + 0.0825*jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + 0.0825*jnp.sin(q_3)*jnp.cos(q_1)

    z = -0.107*((jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - jnp.sin(q_4)*jnp.cos(q_2))*jnp.cos(q_5) - jnp.sin(q_2)*jnp.sin(q_3)*jnp.sin(q_5))*jnp.sin(q_6) - 0.088*((jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - jnp.sin(q_4)*jnp.cos(q_2))*jnp.cos(q_5) - jnp.sin(q_2)*jnp.sin(q_3)*jnp.sin(q_5))*jnp.cos(q_6) + 0.088*(jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + jnp.cos(q_2)*jnp.cos(q_4))*jnp.sin(q_6) - 0.107*(jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + jnp.cos(q_2)*jnp.cos(q_4))*jnp.cos(q_6) + 0.384*jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + 0.0825*jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - 0.0825*jnp.sin(q_2)*jnp.cos(q_3) - 0.0825*jnp.sin(q_4)*jnp.cos(q_2) + 0.384*jnp.cos(q_2)*jnp.cos(q_4) + 0.316*jnp.cos(q_2) + 0.33

    return (x, y, z)


def traj_cost(trajectory):
    cost = 0
    cart_cost = 0
    for i in range(len(trajectory) - 1):
        cost += np.linalg.norm(np.asarray(trajectory[i]) - np.asarray(trajectory[i + 1]), ord=2)
        # pdb.set_trace()
        current = np.asarray(fk_frankatraj(trajectory[i]))
        nextq = np.asarray(fk_frankatraj(trajectory[i + 1]))
        cart_cost += np.linalg.norm(current - nextq , ord=2)
    return cost, cart_cost



def plotdebug(costResidualValue, TrajectoryValue,JointCostValue, CartCostValue, costResidual, Trajectory, JointCost, CartCost ,init_joint, end_cartesian, itrValue, itr,
              itrre,ValueCostValue,ValueCost,ValueOptimalCost,OptCost,ValueJacfranka,Jacfranka, ValueCostTerm,CostTerm,qDotValue,
              qDot , plotno):
    x_fin = end_cartesian.item(0)
    y_fin = end_cartesian.item(1)
    z_fin = end_cartesian.item(2)
    pos = fk_frankatraj(np.asarray(init_joint))
    # pos = init_joint
    x_init = pos[0]
    y_init = pos[1]
    z_init = pos[2]

    countValue = len(TrajectoryValue)
    count = len(Trajectory)
    xopt_solValue = np.zeros(countValue - 1)
    yopt_solValue = np.zeros(countValue - 1)
    zopt_solValue = np.zeros(countValue - 1)
    xopt_sol = np.zeros(count - 1)
    yopt_sol = np.zeros(count - 1)
    zopt_sol = np.zeros(count - 1)
    # pdb.set_trace()
    for i in range(0, countValue - 1):
        pos = fk_frankatraj(TrajectoryValue[i])
        xopt_solValue[i] = pos[0]
        yopt_solValue[i] = pos[1]
        zopt_solValue[i] = pos[2]
    for i in range(0, count - 1):
        pos = fk_frankatraj(Trajectory[i])
        xopt_sol[i] = pos[0]
        yopt_sol[i] = pos[1]
        zopt_sol[i] = pos[2]

    fig = plt.figure(1, figsize=(12, 8), dpi=100)
    plt.title("Trajectory Plot in cartesian coordinate")
    ax = fig.add_subplot(111, projection='3d')
    leg = ax.legend()

    ax.plot(xopt_solValue, yopt_solValue, zopt_solValue, '--or', linewidth=2.0, markersize=6.0,
            label=('with Valfun; Trajcost in joint Space=', JointCostValue, 'in cart Space=',
                   CartCostValue, 'final cost residual', "{:.4f}".format(costResidualValue[-1]), 'itr=', itrValue))#,'Value Cost=',ValueCostValue))
    ax.plot(xopt_sol, yopt_sol, zopt_sol, '--og', linewidth=2.0, markersize=6.0,
            label=(
                'without Valfun; Trajcost in joint Space=', JointCost, 'in cart Space=', CartCost,
                'final cost residual', "{:.4f}".format(costResidual[-1]), 'itr=', itr))#,' Value cost=' ,ValueCost))
    ax.plot(x_init * np.ones(1), y_init * np.ones(1), z_init * np.ones(1), 'om', markersize=15)
    ax.plot(x_fin * np.ones(1), y_fin * np.ones(1), z_fin * np.ones(1), 'og', markersize=10)
    ax.set_xlim3d(-1.0, 1.0)
    ax.set_ylim3d(-1.0, 1.0)
    ax.set_zlim3d(-0.3, 1.2)
    ax.legend(loc='upper left', frameon=False)
    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')
    plt.savefig(f"plottraj_{plotno}__debug")
    #plt.close(fig)
    fig2 = plt.figure(2, figsize=(12, 8), dpi=100)
    plt.title("Cost residual distance cost  VS iteration")
    plt.plot(costResidualValue, label=(
        'with value function'))
    plt.plot(costResidual, label=(
        'Without '))
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotItr__{plotno}_debug")
    
    
    """"plt.figure(3, figsize=(12, 8), dpi=100)
    fig3 = plt.title("Value function cost  VS iteration")
    plt.plot(ValueOptimalCost, label=(
        'with value function'))
    plt.plot(OptCost, label=(
        'Without '))
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotValuecost__{plotno}_bdebug")
    #plt.close(fig2)

    #plt.close(fig2)
    
    fig4 = plt.figure(4, figsize=(12, 8), dpi=100)
    plt.title("Det (Jacobain)   VS iteration")
    plt.plot(ValueJacfranka, label=(
        'with value function'))
    plt.plot(Jacfranka, label=(
        'Without '))
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotDet__{plotno}_debug")
    
    fig5 = plt.figure(5, figsize=(12, 8), dpi=100)
    plt.title("GradTerm     VS iteration")
    plt.plot(ValueCostTerm, label=(
        'with value function'))

    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotgrad_with__{plotno}_debug")

    fig5 = plt.figure(6, figsize=(12, 8), dpi=100)
    plt.title("GradTerm    VS iteration")
    plt.plot(CostTerm, label=(
        'Without '))
    plt.legend(loc='upper left', frameon=False)
    plt.savefig(f"plotgrad_without__{plotno}_debug")"""

    #plt.close(fig4)

    """plt.figure(3, figsize=(12, 8), dpi=100)
    plt.title("withValuefunction")
    trajct = np.asarray(TrajectoryValue)
    plt.plot(trajct[:-1, 0], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:-1, 1], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:, 2], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:, 3], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:, 4], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:, 5], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct[:, 6], '-o', linewidth=3.0, markersize=6.0)"""
    """plt.figure(4, figsize=(12, 8), dpi=100)
    plt.title("withOUT Valuefunction")
    trajct2 = np.asarray(Trajectory)
    plt.plot(trajct2[:-1, 0], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:-1, 1], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:, 2], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:, 3], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:, 4], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:, 5], '-o', linewidth=3.0, markersize=6.0)
    plt.plot(trajct2[:, 6], '-o', linewidth=3.0, markersize=6.0)
    plt.figure(5, figsize=(12, 8), dpi=100)
    plt.title("qdot withValuefunction kp = 1 ")
    trajct = np.asarray(qDotValue)
    plt.plot(trajct[:-1, 0], '-o', linewidth=1.0, markersize=2.0 , label=("joint-1"))
    plt.plot(trajct[:-1, 1], '-o', linewidth=1.0, markersize=2.0, label=("joint-2"))
    plt.plot(trajct[:, 2], '-o', linewidth=1.0, markersize=2.0, label=("joint-3"))
    plt.plot(trajct[:, 3], '-o', linewidth=1.0, markersize=2.0, label=("joint-4"))
    plt.plot(trajct[:, 4], '-o', linewidth=1.0, markersize=2.0, label=("joint-5"))
    plt.plot(trajct[:, 5], '-o', linewidth=1.0, markersize=2.0, label=("joint-6"))
    plt.plot(trajct[:, 6], '-o', linewidth=1.0, markersize=2.0, label=("joint-7"))
    plt.legend(loc='upper left', frameon=False)
    plt.figure(6, figsize=(12, 8), dpi=100)
    plt.title("qDot withOUT Valuefunction kp =10")
    trajct2 = np.asarray(qDot)
    plt.plot(trajct2[:-1, 0], '-o', linewidth=1.0, markersize=2.0 , label=("joint-1"))
    plt.plot(trajct2[:-1, 1], '-o', linewidth=1.0, markersize=2.0, label=("joint-2"))
    plt.plot(trajct2[:, 2], '-o', linewidth=1.0, markersize=2.0, label=("joint-3"))
    plt.plot(trajct2[:, 3], '-o', linewidth=1.0, markersize=2.0, label=("joint-4"))
    plt.plot(trajct2[:, 4], '-o', linewidth=1.0, markersize=2.0, label=("joint-5"))
    plt.plot(trajct2[:, 5], '-o', linewidth=1.0, markersize=2.0, label=("joint-6"))
    plt.plot(trajct2[:, 6], '-o', linewidth=1.0, markersize=2.0, label=("joint-7"))
    plt.legend(loc='upper left', frameon=False)"""

    # pdb.set_trace()
    return

# %%
import pdb

# %%
# # loading Valuefunction

# In[2]:
goal = None

device = 'cpu'
model = torch.load('models/model_750_model_epoch_20000.pth', map_location=torch.device('cpu'))  # loaded trained model
q_dim = 6  # q_dim is the dimension of joint space
q_dim_changed = int(0.5 * q_dim)
weight = []
for key in (model.keys()):
    # print(key)
    weight.append(model[key].cpu().numpy())  # load weight and bias


def leaky_relu(z):
    return jnp.maximum(0.01 * z, z)


def softplus(z, beta=1):
    return (1 / beta) * jnp.log(1 + jnp.exp(z * beta))


def assemble_lower_triangular_matrix(Lo, Ld):
    Lo = Lo.squeeze(0)
    Ld = Ld.squeeze(0)

    assert (2 * Lo.shape[0] == (Ld.shape[0] ** 2 - Ld.shape[0]))
    # pdb.set_trace()
    #     diagonal_matrix = np.diagflat(Ld)
    diagonal_matrix = jnp.identity(len(Ld)) * jnp.outer(jnp.ones(len(Ld)), Ld)

    L = jnp.tril(jnp.ones(diagonal_matrix.shape)) - jnp.eye(q_dim_changed)

    # Set off diagonals

    L = jnp.array([[0, 0, 0], [1, 0, 0], [0, 0, 0]]) * Lo.reshape(3)[0] + jnp.array([[0, 0, 0], [0, 0, 0], [1, 0, 0]]) * \
        Lo.reshape(3)[1] + jnp.array([[0, 0, 0], [0, 0, 0], [0, 1, 0]]) * Lo.reshape(3)[2]
    # print("L now : ", L)
    # Add diagonals
    L = L + diagonal_matrix
    return L


def value_func(x1):
    global weight, goal
    fc1_w = weight[0]
    fc1_b = weight[1]
    fc2_w = weight[2]
    fc2_b = weight[3]
    fc_Ld_w = weight[4]
    fc_Ld_b = weight[5]
    fc_Lo_w = weight[6]
    fc_Lo_b = weight[7]
    
    net_input = jnp.concatenate([x1, jnp.squeeze(goal)], axis =0)
    net_input = jnp.array([net_input])

    z1 = jnp.dot(net_input, fc1_w.transpose()) + fc1_b
    hidden1 = leaky_relu(z1)
    z2 = jnp.dot(hidden1, fc2_w.transpose()) + fc2_b
    hidden2 = leaky_relu(z2)
    hidden3 = jnp.dot(hidden2, fc_Ld_w.transpose()) + fc_Ld_b
    Ld = softplus(hidden3)
    Lo = jnp.dot(hidden2, fc_Lo_w.transpose()) + fc_Lo_b
    L = assemble_lower_triangular_matrix(Lo, Ld)

    H = L @ L.transpose() + 1e-9 * jnp.eye(3)

    # calculating value funcion ie optimal cost   (x1-x2).T*H*(x1-x2)
    x1 = jnp.reshape(net_input[0][:3], (-1, 3))
    goal = jnp.reshape(net_input[0][3:], (-1, 3))
    diff = x1 - goal
    optimalCost = jnp.matmul(diff, jnp.matmul(H, diff.transpose()))
    return optimalCost[0][0]

value_func = jit(vmap(value_func, in_axes=(1)))

def generate_gaussian(mean, cov):
 
  qdot_1,qdot_2, qdot_3, qdot_4, qdot_5, qdot_6, qdot_7 = jax.random.multivariate_normal(key, mean, cov, (50,)).T
  
  return jnp.vstack(( qdot_1, qdot_2, qdot_3, qdot_4, qdot_5, qdot_6, qdot_7  ))



def fk_franka(q_1, q_2, q_3, q_4, q_5, q_6, q_7):
   
    x = -0.107*(((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1))*jnp.cos(q_5) + (jnp.sin(q_1)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1)*jnp.cos(q_2))*jnp.sin(q_5))*jnp.sin(q_6) - 0.088*(((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1))*jnp.cos(q_5) + (jnp.sin(q_1)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1)*jnp.cos(q_2))*jnp.sin(q_5))*jnp.cos(q_6) + 0.088*((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4))*jnp.sin(q_6) - 0.107*((jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4))*jnp.cos(q_6) + 0.384*(jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.sin(q_4) + 0.0825*(jnp.sin(q_1)*jnp.sin(q_3) - jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3))*jnp.cos(q_4) - 0.0825*jnp.sin(q_1)*jnp.sin(q_3) - 0.0825*jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_1) + 0.384*jnp.sin(q_2)*jnp.cos(q_1)*jnp.cos(q_4) + 0.316*jnp.sin(q_2)*jnp.cos(q_1) + 0.0825*jnp.cos(q_1)*jnp.cos(q_2)*jnp.cos(q_3)

    y = 0.107*(((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) + jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4))*jnp.cos(q_5) - (jnp.sin(q_1)*jnp.sin(q_3)*jnp.cos(q_2) - jnp.cos(q_1)*jnp.cos(q_3))*jnp.sin(q_5))*jnp.sin(q_6) + 0.088*(((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) + jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4))*jnp.cos(q_5) - (jnp.sin(q_1)*jnp.sin(q_3)*jnp.cos(q_2) - jnp.cos(q_1)*jnp.cos(q_3))*jnp.sin(q_5))*jnp.cos(q_6) - 0.088*((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4))*jnp.sin(q_6) + 0.107*((jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4))*jnp.cos(q_6) - 0.384*(jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.sin(q_4) - 0.0825*(jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + jnp.sin(q_3)*jnp.cos(q_1))*jnp.cos(q_4) - 0.0825*jnp.sin(q_1)*jnp.sin(q_2)*jnp.sin(q_4) + 0.384*jnp.sin(q_1)*jnp.sin(q_2)*jnp.cos(q_4) + 0.316*jnp.sin(q_1)*jnp.sin(q_2) + 0.0825*jnp.sin(q_1)*jnp.cos(q_2)*jnp.cos(q_3) + 0.0825*jnp.sin(q_3)*jnp.cos(q_1)

    z = -0.107*((jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - jnp.sin(q_4)*jnp.cos(q_2))*jnp.cos(q_5) - jnp.sin(q_2)*jnp.sin(q_3)*jnp.sin(q_5))*jnp.sin(q_6) - 0.088*((jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - jnp.sin(q_4)*jnp.cos(q_2))*jnp.cos(q_5) - jnp.sin(q_2)*jnp.sin(q_3)*jnp.sin(q_5))*jnp.cos(q_6) + 0.088*(jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + jnp.cos(q_2)*jnp.cos(q_4))*jnp.sin(q_6) - 0.107*(jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + jnp.cos(q_2)*jnp.cos(q_4))*jnp.cos(q_6) + 0.384*jnp.sin(q_2)*jnp.sin(q_4)*jnp.cos(q_3) + 0.0825*jnp.sin(q_2)*jnp.cos(q_3)*jnp.cos(q_4) - 0.0825*jnp.sin(q_2)*jnp.cos(q_3) - 0.0825*jnp.sin(q_4)*jnp.cos(q_2) + 0.384*jnp.cos(q_2)*jnp.cos(q_4) + 0.316*jnp.cos(q_2) + 0.33

    return x, y, z


key = random.PRNGKey(0)


def findTrajectory(init_joint, x_des, USeValuefunction=False):
    top_k = 5
    num_samples = 50
    mpc_iter = 3
    trajectory =[]
    t = 0.01
    q = init_joint
    q_min = jnp.array([-165, -100, -165, -165, -165, -1.0, -165  ])*np.pi/180
    q_max = jnp.array([ 165,   101,  165,  1.0,    165, 214, 165  ])*np.pi/180

    q_min_jax = jnp.vstack((q_min[0]*jnp.ones(num_samples), q_min[1]*jnp.ones(num_samples), q_min[2]*jnp.ones(num_samples), q_min[3]*jnp.ones(num_samples), q_min[4]*jnp.ones(num_samples), q_min[5]*jnp.ones(num_samples), q_min[6]*jnp.ones(num_samples)            ))

    q_max_jax = jnp.vstack((q_max[0]*jnp.ones(num_samples), q_max[1]*jnp.ones(num_samples), q_max[2]*jnp.ones(num_samples), q_max[3]*jnp.ones(num_samples), q_max[4]*jnp.ones(num_samples), q_max[5]*jnp.ones(num_samples), q_max[6]*jnp.ones(num_samples)            ))
    qdot = jnp.vstack((0*jnp.ones(num_samples), 0*jnp.ones(num_samples), 0*jnp.ones(num_samples), 0*jnp.ones(num_samples), 0*jnp.ones(num_samples), 0*jnp.ones(num_samples), 0*jnp.ones(num_samples)))
 
    qdot_min = -1.5*jnp.ones(( 7, num_samples   ))
    qdot_max = 1.5*jnp.ones(( 7, num_samples   ))
    Optcost= []    
    cost_tracker = np.zeros(mpc_iter)
    trajectory = []
    Jacfranka = []
    COSTFIRSTTERM =[]
    x_pos = x_des
    for j in range(mpc_iter):
        print(f"j={j}")

        generate_gaussian_jit = jit(generate_gaussian)
        fk_franka_jit = jit(fk_franka)

        cov = 1*jnp.identity(7)
        mean = jnp.ones(7)
        
        for i in range(0, 5):

            qdot_samples = generate_gaussian_jit(mean, cov)

            qdot_samples = jnp.clip(qdot_samples, qdot_min, qdot_max) #######3 kinematically feasible velocities

            q_samples = qdot_samples*t+q[:, jnp.newaxis]
            q_samples = jnp.clip(q_samples, q_min_jax, q_max_jax  ) ################## clipping to min and max values



            x_samples, y_samples, z_samples = fk_franka_jit(q_samples[0,:], q_samples[1,:], q_samples[2,:], q_samples[3,:], q_samples[4,:], q_samples[5,:], q_samples[6,:])
            net_input = jnp.concatenate((x_samples.reshape(1, num_samples), y_samples.reshape(1, num_samples), z_samples.reshape(1, num_samples)), axis=0)
            value_samples = value_func(net_input)

            samples_losses = value_samples+0.0001*jnp.linalg.norm((qdot_samples-qdot).T, axis = 1)

            sorted_index = np.argsort(samples_losses)

            mean = jnp.mean(q_samples.T[sorted_index[0:top_k]], axis=0)

            # cov = jnp.diag(jnp.std(q_samples.T[sorted_index[0:top_k]], axis=0))

        #pdb.set_trace()
        cost_tracker[j] = np.array(jnp.linalg.norm(jnp.hstack((x_pos[0] - x_des[0], x_pos[1] - x_des[1], x_pos[2] - x_des[2]))))
        qdot_sol = mean
        trajectory.append([q[0], q[1], q[2], q[3], q[4], q[5], q[6]])
        q = q+qdot_sol*t
        q = jnp.clip(q, q_min, q_max)
        x, y, z = fk_franka_jit(q[0], q[1], q[2], q[3], q[4], q[5], q[6])
        x_pos[0] = x
        x_pos[1] = y
        x_pos[2] = z
    JointCost, CartCost = traj_cost(trajectory)
    print((f"USeValuefunction=", {i}) if USeValuefunction else (f"WithoutUSeValuefunction=", {i}))
    return JointCost, CartCost, j, cost_tracker, trajectory, Optcost , Jacfranka, COSTFIRSTTERM

# %%
import psutil
import os
import gc

def memory_usage_psutil():
    # return the memory usage in percentage like top
    process = psutil.Process(os.getpid())
    mem = process.memory_percent()
    return mem


#from EvaluateValue import*

consume_memory = range(20 * 1000 * 1000)
if __name__ == "__main__":
    StatCartcost = []
    StatJointcost = []
    StatIteration = []

    i = 0

    #TRAJ_train = TrajectoryDataset_customScipy()
    #trainloader = DataLoader(TRAJ_train, batch_size=1, drop_last=True, shuffle=True)
    itrer = 45
    #for x, y, net_input, cost, start_joint, end_joint in trainloader:
    mempercent = memory_usage_psutil()
    print("episode number=", itrer, " memory percentage=", mempercent)
    #x = x.to(device).numpy()
    #y = y.to(device).numpy()
    #net_input = net_input.to(device).numpy()
    #cost = cost.to(device).numpy()
    #start_joint = np.squeeze(start_joint.to(device).numpy())
    #init_joint = start_joint
    #start_goalMatrx = robot.fkine(np.asarray(init_joint)).A
    #start_cartesian = start_goalMatrx[:3, -1]

    #end_joint = np.squeeze(end_joint.to(device).numpy())
    #end_goalMatrx = robot.fkine(np.asarray(end_joint)).A
    #end_cartesian = end_goalMatrx[:3, -1]
    #print()
    # "(array([ 0.02993148, -0.81388898,  0.68629719]), array([ 0.48676868, -0.62025949,  0.30601166]))", "(1.4064189916326066, 0.715743368535722, 409, 0.0)", "(0.9107242155900203, 0.6375860839986414, 140, 0.0)"
    # start_cartesian = np.asarray([-0.64138634, -0.1121935, 0.37439369])
    # end_cartesian = np.asarray([0.41278069, -0.588507, 0.63967752])
    """init_joint = np.asarray(
    [2.14449164 ,-1.03954174 , 1.48352234, -2.41364852 ,-2.94330321  ,3.7030148 ,1.21567664])
    start_cartesian = np.asarray([-0.3573407 , -0.09592867,  0.25939623])
    end_cartesian = np.asarray([ 0.24699985, -0.34406714,  0.06485374])"""
    #sample 4_debug
    """init_joint = np.asarray(
    [0.84382422 ,-1.75234566 ,-1.69086123 ,-2.25043335, 0.57998683,  1.20356413, -2.5246048 ])
    start_cartesian = np.asarray([ 0.24605024, -0.22180356,  0.41969074])
    end_cartesian = np.asarray([ 0.54354027, -0.32576192,  0.0149268 ])"""
    #Sample5_debug
    init_joint = np.asarray(
    [2.47825829 , -1.61507985,  1.37275587 ,-1.93516424 ,-2.8128795 ,  1.09669481 , -0.45580737 ])
    start_cartesian = np.asarray([ 0.05922296, -0.68850508,  0.48861248])
    end_cartesian = np.asarray([ 0.6367232 , -0.40827509,  0.39513954])
    
    #sample 6

    """init_joint = np.asarray(
    [ 1.75890144 , -0.04687897 , 2.63947177, -1.76993654 , 0.12950717 , 0.70154342 ,0.41454053 ])
    start_cartesian = np.asarray([-0.07702687, -0.33196785,  0.46285633])
    end_cartesian = np.asarray([ 0.16535281, -0.55448692,  0.08841983])"""

    print("Start : ", start_cartesian)
    print("Goal : ", end_cartesian)
    goal = np.squeeze(end_cartesian)
    JointCostValue, CartCostValue, itrValue, cost_trackerValue, TrajectoryValue, ValueOptCost , ValueJacfranka, ValueCostTerm = findTrajectory(init_joint,
                                                                                                end_cartesian,
                                                                                                True)
    JointCost, CartCost, itr, cost_tracker, Trajectory,OptCost, Jacfranka,CostTerm  = findTrajectory(init_joint, end_cartesian, False)
    ValueCostValue =0 # EvaluateValuefunction(TrajectoryValue,start_cartesian,end_cartesian)
    ValueCost=0 #EvaluateValuefunction(Trajectory,start_cartesian,end_cartesian)
    itrer += 1
    plotdebug(cost_trackerValue, TrajectoryValue,JointCostValue, CartCostValue, cost_tracker, Trajectory, JointCost, CartCost , init_joint, end_cartesian, 
            itrValue, itr,itrer, ValueCostValue,ValueCost,ValueOptCost,OptCost, ValueJacfranka,Jacfranka,ValueCostTerm,CostTerm,
            qDotValue=0, qDot=0,plotno=999)            
    

    """with open('weight_data_debug_new.csv', 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([(init_joint), (start_cartesian, end_cartesian),
                        (JointCostValue, CartCostValue, itrValue, cost_trackerValue[-1]),
                        (JointCost, CartCost, itr, cost_tracker[-1])])"""

gc.collect()
exit()
# Out:
# episode number= 45  memory percentage= 0.6342525137401644
# Start :  [ 0.05922296 -0.68850508  0.48861248]
# Goal :  [ 0.6367232  -0.40827509  0.39513954]
# j=0
# j=1
# j=2
# ('USeValuefunction=', {4})
# j=0
# j=1
# j=2
# ('WithoutUSeValuefunction=', {4})
# <ipython-input-33-0fadfd58ebf5>:65: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(111, projection='3d')
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# $\theta$
